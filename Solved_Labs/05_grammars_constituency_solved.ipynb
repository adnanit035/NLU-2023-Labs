# %% [markdown]
# # Constituency Grammars with NLTK

# %% [markdown]
# ## Objectives
# - Understanding:
#     - relation between grammar and syntactic parse tree
#     - relation between grammar and syntactic categories
#     - relation between grammar and Part-of-Speech tags
#     - context free grammars (CFG)
#     - probabilistic context free grammars (PCFG)
# - Learning how to:
#     - define CFG in NLTK
#     - parse with CFG
#     - learn PCFGs from a treebank
#     - parse with PCFG
#     - generate sentences using a grammar in NLTK
#     - evaluate parser

# %% [markdown]
# ### Recommended Reading
# - Dan Jurafsky and James H. Martin. [__Speech and Language Processing__ (SLP)](https://web.stanford.edu/~jurafsky/slp3/) (3rd ed. draft)
# - Steven Bird, Ewan Klein, and Edward Loper. [__Natural Language Processing with Python__ (NLTK)](https://www.nltk.org/book/)

# %% [markdown]
# ### Covered Material
# - SLP
#     - [Chapter 17: Context-Free Grammars and Constituency Parsing](https://web.stanford.edu/~jurafsky/slp3/17.pdf)
# - NLTK
#     - [Chapter 8: Analyzing Sentence Structure](https://www.nltk.org/book/ch08.html)

# %% [markdown]
# ### Requirements
#
# - [NLTK](https://www.nltk.org/)

# %% [markdown]
# ## 1. Grammars, Production Rules, and Parse Trees

# %% [markdown]
# In linguistics, [**syntax**](https://en.wikipedia.org/wiki/Syntax) is the study of how words and morphemes combine to form larger units such as phrases and sentences. Central concerns of syntax include word order, **grammatical relations**, **hierarchical sentence structure** (constituency), agreement, the nature of crosslinguistic variation, and the relationship between form and meaning.

# %% [markdown]
# In linguistics, the [**grammar**](https://en.wikipedia.org/wiki/Grammar) of a natural language is its set of structural constraints on speakers' or writers' composition of clauses, phrases, and words.

# %% [markdown]
# A [**context-free grammar (CFG)**](https://en.wikipedia.org/wiki/Context-free_grammar) is a formal grammar whose [**production rules**](https://en.wikipedia.org/wiki/Production_(computer_science)) are of the form:
#
# $$A \to \alpha$$
#
# where:
# - $A$ a single nonterminal symbol
# - $\alpha$  a string of terminals and/or nonterminals

# %% [markdown]
# [**Parsing**](https://en.wikipedia.org/wiki/Parsing), syntax analysis, or syntactic analysis is the process of analyzing a string of symbols, either in natural language, computer languages or data structures, conforming to the rules of a formal grammar.
# Within computational linguistics the term is used to refer to the formal analysis by a computer of a sentence or other string of words into its **constituents**, resulting in a **parse tree** showing their syntactic relation to each other.

# %% [markdown]
# A [**parse tree**](https://en.wikipedia.org/wiki/Parse_tree) or **parsing tree** or **derivation tree** or **concrete syntax tree** is an ordered, rooted tree that represents the syntactic structure of a string according to some **context-free grammar**. The term parse tree itself is used primarily in computational linguistics; in theoretical syntax, the term syntax tree is more common.

# %% [markdown]
# ### 1.1. Parse Tree Representation
# One of the possible parse trees for a sentence `I saw the man with a telescope` is as below:

# %% [markdown]
# ```
#       S
#   ____|___________
#  |                VP
#  |     ___________|________
#  |    |       |            PP
#  |    |       |        ____|___
#  NP   |       NP      |        NP
#  |    |    ___|___    |     ___|______
# PRON  V  Det      N   P   Det         N
#  |    |   |       |   |    |          |
#  I   saw the     man with  a      telescope
#  ```

# %% [markdown]
# To occupy less space, a parse tree is usually represented using "bracketed expressions", where brackets enclose each **constituent** and the first element of the expression is the tree-node label.
#
# ```
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man))
#     (PP (P with) (NP (Det a) (N telescope)))))
# ```

# %% [markdown]
# It is common to write a parse tree in a less readable one-line expression:
#
# ```
# (S (NP (PRON I)) (VP (V saw) (NP (Det the) (N man)) (PP (P with) (NP (Det a) (N telescope)))))
# ```

# %% [markdown]
# ### 1.2. Parse Trees in NLTK

# %% [markdown]
# NLTK provides `Tree` class for representing hierarchical language structures. The class implements many useful methods. <br> Full documentation [HERE](https://www.nltk.org/api/nltk.tree.tree.html)

# %% [markdown]
# #### 1.2.1. "Core" Methods
#
# - `fromstring()` reads a bracketed tree string and return the resulting tree
#
# - `productions()` generate the productions that correspond to the non-terminal nodes of the tree.
#     - For each subtree of the form `(P: C1 C2 ... Cn)` this produces a production of the form `P -> C1 C2 ... Cn`.
#
# - `label()` returns the node label of the tree
#
# - `subtrees()` generates all the subtrees of this tree
#
# - `pos()` return a sequence of pos-tagged words extracted from the tree.
#
# - `leaves()` returns the leaves of the tree.
#
# - `flatten()` return a flat version of the tree, with all non-root non-terminals removed.

# %%
from nltk.tree import Tree
sent = "I saw the man with a telescope"
parse_tree_str = "(S (NP (PRON I)) (VP (V saw) (NP (Det the) (N man)) (PP (P with) (NP (Det a) (N telescope)))))"

tree = Tree.fromstring(parse_tree_str)

# %%
# production rules of tree
tree.productions()
# Out:
# [S -> NP VP,
#  NP -> PRON,
#  PRON -> 'I',
#  VP -> V NP PP,
#  V -> 'saw',
#  NP -> Det N,
#  Det -> 'the',
#  N -> 'man',
#  PP -> P NP,
#  P -> 'with',
#  NP -> Det N,
#  Det -> 'a',
#  N -> 'telescope']

# %%
# print node of the tree
print(tree.label())
# Out:
# S

# %%
# prints leaves of the tree
print(tree.leaves())
# Out:
# ['I', 'saw', 'the', 'man', 'with', 'a', 'telescope']

# %%
# flatten the tree
print(tree.flatten())
# Out:
# (S I saw the man with a telescope)

# %%
# prints bracketed expression for the parse tree
print(tree)
# Out:
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man))
#     (PP (P with) (NP (Det a) (N telescope)))))

# %%
# prints all the subtrees
for stree in tree.subtrees():
    print('-' * 89)
    print(stree)
# Out:
# -----------------------------------------------------------------------------------------
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man))
#     (PP (P with) (NP (Det a) (N telescope)))))
# -----------------------------------------------------------------------------------------
# (NP (PRON I))
# -----------------------------------------------------------------------------------------
# (PRON I)
# -----------------------------------------------------------------------------------------
# (VP
#   (V saw)
#   (NP (Det the) (N man))
#   (PP (P with) (NP (Det a) (N telescope))))
# -----------------------------------------------------------------------------------------
# (V saw)
# -----------------------------------------------------------------------------------------
# (NP (Det the) (N man))
# -----------------------------------------------------------------------------------------
# (Det the)
# -----------------------------------------------------------------------------------------
# (N man)
# -----------------------------------------------------------------------------------------
# (PP (P with) (NP (Det a) (N telescope)))
# -----------------------------------------------------------------------------------------
# (P with)
# -----------------------------------------------------------------------------------------
# (NP (Det a) (N telescope))
# -----------------------------------------------------------------------------------------
# (Det a)
# -----------------------------------------------------------------------------------------
# (N telescope)

# %% [markdown]
# #### 1.2.2 Visualizaing Parse Trees
#
# In the code above, we have printed the parse tree using `print()` method, which prints a _bracketed expression_ tree.
# It is also possible to visualize syntactic trees of using other method:
#
# - `pprint()` the same as above
# - `pretty_print()` draws ASCII tree (the original example)
# - `draw()` opens a new window containing a graphical diagram of this tree.
# - `tree` a call to a tree draws it using `svgling`
#     - requires `svgling` module to be installed (`pip install svgling`)
#     - GitHub https://github.com/rawlins/svgling

# %%
tree.pretty_print(unicodelines=True, nodedist=4)
# Out:
#          S
#  ┌───────┴────────────────────┐
#  │                            VP
#  │       ┌─────────────┬──────┴──────────────┐
#  │       │             │                     PP
#  │       │             │             ┌───────┴──────┐
#  NP      │             NP            │              NP
#  │       │      ┌──────┴──────┐      │       ┌──────┴─────────┐
# PRON     V     Det            N      P      Det               N
#  │       │      │             │      │       │                │
#  I      saw    the           man    with     a            telescope

# %%
tree.pprint()
# Out:
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man))
#     (PP (P with) (NP (Det a) (N telescope)))))

# %%
tree.pretty_print()
# Out:
#       S
#   ____|___________
#  |                VP
#  |     ___________|________
#  |    |       |            PP
#  |    |       |        ____|___
#  NP   |       NP      |        NP
#  |    |    ___|___    |     ___|______
# PRON  V  Det      N   P   Det         N
#  |    |   |       |   |    |          |
#  I   saw the     man with  a      telescope

# %%
tree.draw()

# %%
from pprint import pprint

pprint(tree)
# Out:
# Tree('S', [Tree('NP', [Tree('PRON', ['I'])]), Tree('VP', [Tree('V', ['saw']), Tree('NP', [Tree('Det', ['the']), Tree('N', ['man'])]), Tree('PP', [Tree('P', ['with']), Tree('NP', [Tree('Det', ['a']), Tree('N', ['telescope'])])])])])

# %% [markdown]
# #### Exercise
# Familiarize with the [`Tree`](https://www.nltk.org/api/nltk.tree.tree.html) class.
#
# - Consult the documentation for more detail (and other methods)
# - Try each of the "core" methods listed above
#     - see production rules, leaves, and pos
#
# ######   "Core" Methods
#
# - `fromstring()` reads a bracketed tree string and return the resulting tree
#
# - `productions()` generate the productions that correspond to the non-terminal nodes of the tree.
#     - For each subtree of the form `(P: C1 C2 ... Cn)` this produces a production of the form `P -> C1 C2 ... Cn`.
#
# - `label()` returns the node label of the tree
#
# - `subtrees()` generates all the subtrees of this tree
#
# - `pos()` return a sequence of pos-tagged words extracted from the tree.
#
# - `leaves()` returns the leaves of the tree.
#
# - `flatten()` return a flat version of the tree, with all non-root non-terminals removed.

# %%
# Productions
print('Productions:')
pprint(tree.productions())
# Out:
# Productions:
# [S -> NP VP,
#  NP -> PRON,
#  PRON -> 'I',
#  VP -> V NP PP,
#  V -> 'saw',
#  NP -> Det N,
#  Det -> 'the',
#  N -> 'man',
#  PP -> P NP,
#  P -> 'with',
#  NP -> Det N,
#  Det -> 'a',
#  N -> 'telescope']

# %%
# Label
print('Label:',tree[1].label())
# Out:
# Label: VP

# %%
# Pos tags
print('Pos Tags:', tree.pos())
# Out:
# Pos Tags: [('I', 'PRON'), ('saw', 'V'), ('the', 'Det'), ('man', 'N'), ('with', 'P'), ('a', 'Det'), ('telescope', 'N')]

# %%
# Leaves
print('Leaves:', tree.leaves())
# Out:
# Leaves: ['I', 'saw', 'the', 'man', 'with', 'a', 'telescope']

# %%
# Flatten
print('Flatten:', tree.flatten())
# Out:
# Flatten: (S I saw the man with a telescope)

# %% [markdown]
# ## 2. Context Free Grammars (CFG)

# %% [markdown]
# ### 2.1. Defining Context Free Grammars
#
# CFG are defined by a *start symbol* and a set of *production rules*. The *start symbol* defines the root node of parse trees (usually __S__).
#
# *Production rules* specify allowed parent-child relations in a parse tree. Each production specifies what node can be the parent of a particular set of children nodes.
#
# For example, the production `S -> NP VP` specifies that an `S` node can be the parent of an `NP` node and a `VP` node.
#
# The left-hand side of a production rules specifies potential *non-terminal* parent nodes; while right-hand side specifies list of allowed *non-terminal* and *terminal* (text) children.
#
# A production like `VP -> V NP | VP PP` has a disjunction on the right-hand side, shown by the `|` and is an abbreviation for the two productions `VP -> V NP` and `VP -> V NP PP`.

# %% [markdown]
# #### 2.1.1 Syntactic Categories
#
# | __Symbol__ | __Meaning__ | __Example__ |
# |:-----------|:------------|:------------|
# | S   | sentence             | I saw the man |
# | NP  | noun phrase          | the man |
# | VP  | verb phrase          | saw the man |
# | PP  | prepositional phrase | with a telescope |
# | Det | determiner  | the |
# | N   | noun        | man |
# | V   | verb        | saw |
# | P   | preposition | with |
#
#
# - Non-Terminals: `S`, `NP`, `VP`, `PP`
# - Pre-Terminals: `Det`, `N`, `V`, `P` (Part-of-Speech Tags)
# - Terminals (Leaves): the, man, saw, ...

# %% [markdown]
# ### 2.2. Defining Context Free Grammars in NLTK
#
# The grammar can be defined as a string or as a list of strings of production rules.

# %%
import nltk

rules = [
    'S -> NP VP',
    'NP -> Det N | Det N PP | PRON',
    'VP -> V NP | V NP PP',
    'PP -> P NP',
    'Det -> "the" | "a"',
    'N -> "man" | "telescope"',
    'PRON -> "I"',
    'V -> "saw"',
    'P -> "with"'
]

toy_grammar = nltk.CFG.fromstring(rules)

print(toy_grammar)
# Out:
# Grammar with 14 productions (start state = S)
#     S -> NP VP
#     NP -> Det N
#     NP -> Det N PP
#     NP -> PRON
#     VP -> V NP
#     VP -> V NP PP
#     PP -> P NP
#     Det -> 'the'
#     Det -> 'a'
#     N -> 'man'
#     N -> 'telescope'
#     PRON -> 'I'
#     V -> 'saw'
#     P -> 'with'

# %% [markdown]
# Grammar object has 2 components:
# - start symbol
# - production rules
#
# Those can be access as follows.

# %%
print(toy_grammar.start())
# Out:
# S

# %%
print(toy_grammar.productions())
# Out:
# [S -> NP VP, NP -> Det N, NP -> Det N PP, NP -> PRON, VP -> V NP, VP -> V NP PP, PP -> P NP, Det -> 'the', Det -> 'a', N -> 'man', N -> 'telescope', PRON -> 'I', V -> 'saw', P -> 'with']

# %% [markdown]
# Each production has 2 parts:
# - left-hand side
# - right-hand side
#
# which can be accessed as follows:

# %%
rule = toy_grammar.productions()[0]
print(rule.lhs())
print(rule.rhs())
# Out:
# S
# (NP, VP)

# %% [markdown]
# __Grammar__'s `productions(lhs=None, rhs=None, empty=False)` methods returns the grammar productions, filtered by the left-hand side or the first item in the right-hand side.
#
# __Parameters__
# - `lhs` -- Only return productions with the given left-hand side.
# - `rhs` -- Only return productions with the given first item in the right-hand side.
# - `empty` -- Only return productions with an empty right-hand side

# %%
from nltk import Nonterminal
toy_grammar.productions(lhs=Nonterminal('NP'))
# Out:
# [NP -> Det N, NP -> Det N PP, NP -> PRON]

# %%
toy_grammar.productions(rhs=Nonterminal('NP'))
# Out:
# [S -> NP VP]

# %%
toy_grammar.productions(empty=True)
# Out:
# dict_values([])

# %% [markdown]
# ### 2.3. Parsing with CFG
#
# > A parser processes input sentences according to the productions of a grammar, and builds one or more constituent structures that conform to the grammar. A grammar is a declarative specification of well-formedness — it is actually just a string, not a program. A parser is a procedural interpretation of the grammar. It searches through the space of trees licensed by a grammar to find one that has the required sentence along its fringe (outer edges).

# %% [markdown]
# #### 2.3.1. Available CFG Parsers in NLTK
#
# - Recursive descent parsing
#     - top-down algorithm
#     - pro: finds all successful parses.
#     - con: inefficient. will try all rules brute-force, even the ones that do not match the input. Goes into an infinite loop when handling a left-recursive rule.
#     - `nltk.RecursiveDescentParser()`
#
# - Shift-reduce parsing
#     - bottom-up algorithm
#     - pro: efficient. only works with the rules that match input words.
#     - con: may fail to find a legitimate parse even when there is one.
#     - `nltk.ShiftReduceParser()`
#
# - The left-corner parser
#     - a top-down parser with bottom-up filtering
#     - `nltk.LeftCornerChartParser()`: combines left-corner parsing and chart parsing
#
# - Chart parsing
#     - utilizes dynamic programming: builds and refers to well-formed substring tables (WFST)
#     - pro: efficient.
#     - con: may take up a big memory space when dealing with a long sentence.
#     - `nltk.ChartParser()`

# %%
rules = [
    'S -> NP VP',
    'NP -> Det N | PRON ',
    'NP -> Det N PP',
    'VP -> V NP | V NP PP',
    'PP -> P NP',
    'Det -> "the" | "a"',
    'N -> "man" | "telescope"',
    'PRON -> "I"',
    'V -> "saw"',
    'P -> "with"'
]

toy_grammar = nltk.CFG.fromstring(rules)

# %%
parser = nltk.ChartParser(toy_grammar)

sent = "I saw the man with a telescope"

for tree in parser.parse(sent.split()):
    print(tree)
# Out:
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man))
#     (PP (P with) (NP (Det a) (N telescope)))))
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man) (PP (P with) (NP (Det a) (N telescope))))))

# %%
parser = nltk.RecursiveDescentParser(toy_grammar)

sent = "I saw the man with a telescope"

for tree in parser.parse(sent.split()):
    print(tree)
# Out:
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man) (PP (P with) (NP (Det a) (N telescope))))))
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man))
#     (PP (P with) (NP (Det a) (N telescope)))))

# %%
parser = nltk.ShiftReduceParser(toy_grammar)

sent = "I saw the man with a telescope"

for tree in parser.parse(sent.split()):
    print(tree)

# %%
parser = nltk.LeftCornerChartParser(toy_grammar)

sent = "I saw the man with a telescope"

for tree in parser.parse(sent.split()):
    print(tree)
# Out:
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man))
#     (PP (P with) (NP (Det a) (N telescope)))))
# (S
#   (NP (PRON I))
#   (VP
#     (V saw)
#     (NP (Det the) (N man) (PP (P with) (NP (Det a) (N telescope))))))

# %% [markdown]
# The sentence produces two possible parse trees. Thus, it is said to be structurally ambiguous -- prepositional phrase attachment ambiguity.

# %% [markdown]
# #### Exercise
#
# - Define grammar that covers the following sentences.
#
#     - show flights from new york to los angeles
#     - list flights from new york to los angeles
#     - show flights from new york
#     - list flights to los angeles
#     - list flights
# - Use one of the parsers to parse the sentences (i.e. test your grammar)
#
# **Note:** <br>
# - start from Verb Pharse
# - Prepositional Phrase (PP) are composed of a preposition and a Noun Phrase
# - 'los' and 'angeles' are two consecutive nouns (N) (same for new york)
#
# #### Useful reminder from above
#
#
# | __Symbol__ | __Meaning__ | __Example__ |
# |:-----------|:------------|:------------|
# | S   | sentence             | I saw the man |
# | NP  | noun phrase          | the man |
# | VP  | verb phrase          | saw the man |
# | PP  | prepositional phrase | with a telescope |
# | Det | determiner  | the |
# | N   | noun        | man |
# | V   | verb        | saw |
# | P   | preposition | with |
#
#
# - Non-Terminals: `S`, `NP`, `VP`, `PP`
# - Pre-Terminals: `Det`, `N`, `V`, `P` (Part-of-Speech Tags)
# - Terminals (Leaves): the, man, saw, ...

# %%
# test sentences
test_sents = [
    "show flights from new york to los angeles", 
    "list flights from new york to los angeles",
    "show flights from new york",
    "list flights to los angeles",
    "list flights"
]

# %%
rules = [
    "S -> VP | VP PP",
    "VP -> Verb NP | Verb NP PP | Verb PP",
    "NP -> Det Noun | Det Noun PP | Noun",
    "PP -> Preposition NP",
    "Det -> 'show' | 'list'",
    "Noun -> 'flights' | 'new' 'york' | 'los' 'angeles'",
    "Verb -> 'show' | 'list'",
    "Preposition -> 'from' | 'to'"
]

toy_grammar = nltk.CFG.fromstring(rules)

# %%
parser = nltk.ChartParser(toy_grammar)

for sent in test_sents:
    for tree in parser.parse(sent.split()):
        print(tree.pretty_print())
# Out:
#                           S
#                    _______|_________________________
#                   VP                                |
#   ________________|_______                          |
#  |      |                 PP                        PP
#  |      |          _______|___               _______|___
#  |      NP        |           NP            |           NP
#  |      |         |           |             |           |
# Verb   Noun  Preposition     Noun      Preposition     Noun
#  |      |         |        ___|____         |        ___|______
# show flights     from    new      york      to     los      angeles
#
# None
#                           S
#                    _______|_________________________
#                   VP                                |
#   ________________|_______                          |
#  |      |                 PP                        PP
#  |      |          _______|___               _______|___
#  |      NP        |           NP            |           NP
#  |      |         |           |             |           |
# Verb   Noun  Preposition     Noun      Preposition     Noun
#  |      |         |        ___|____         |        ___|______
# list flights     from    new      york      to     los      angeles
#
# None
#                       S
#        _______________|_______
#       VP                      PP
#   ____|_____           _______|___
#  |          NP        |           NP
#  |          |         |           |
# Verb       Noun  Preposition     Noun
#  |          |         |        ___|____
# show     flights     from    new      york
#
# None
#                   S
#                   |
#                   VP
#   ________________|_______
#  |      |                 PP
#  |      |          _______|___
#  |      NP        |           NP
#  |      |         |           |
# Verb   Noun  Preposition     Noun
#  |      |         |        ___|____
# show flights     from    new      york
#
# None
#                       S
#        _______________|_______
#       VP                      PP
#   ____|_____           _______|___
#  |          NP        |           NP
#  |          |         |           |
# Verb       Noun  Preposition     Noun
#  |          |         |        ___|______
# list     flights      to     los      angeles
#
# None
#                   S
#                   |
#                   VP
#   ________________|_______
#  |      |                 PP
#  |      |          _______|___
#  |      NP        |           NP
#  |      |         |           |
# Verb   Noun  Preposition     Noun
#  |      |         |        ___|______
# list flights      to     los      angeles
#
# None
#       S
#       |
#       VP
#   ____|_____
#  |          NP
#  |          |
# Verb       Noun
#  |          |
# list     flights
#
# None

# %% [markdown]
# ### 2.3.2. "Real" Grammars

# %% [markdown]
# It is possible to load a grammar written by someone else into NLTK.
#
# - run `nltk.download()`
# - go to `Models` tab
# - download `large_grammars`

# %%
nltk.download('large_grammars')
# Out:
# [nltk_data] Downloading package large_grammars to
# [nltk_data]     C:\Users\adnan\AppData\Roaming\nltk_data...
# [nltk_data]   Package large_grammars is already up-to-date!
# True

# %%
atis_grammar = nltk.data.load('grammars/large_grammars/atis.cfg')
atis_parser = nltk.ChartParser(atis_grammar)

# %%
atis_grammar
# Out:
# <Grammar with 5517 productions>

# %%
atis_grammar.start()
# Out:
# SIGMA

# %%
atis_grammar.productions()[0]
# Out:
# ABBCL_NP -> QUANP_DTI QUANP_DTI QUANP_CD AJP_JJ NOUN_NP PRPRTCL_VBG

# %% [markdown]
# The grammar comes with some test sentences.

# %%
atis_test_sentences = nltk.data.load('grammars/large_grammars/atis_sentences.txt')
atis_test_sentences = nltk.parse.util.extract_test_sentences(atis_test_sentences)
print(atis_test_sentences[0])
# Out:
# (['i', 'need', 'a', 'flight', 'from', 'charlotte', 'to', 'las', 'vegas', 'that', 'makes', 'a', 'stop', 'in', 'saint', 'louis', '.'], 2085)

# %% [markdown]
# Each test sentence is a tuple of a list of sentence words and a number of possible parses with respect to the grammar.

# %%
# let's check the number of parses our parser produces
for sent, pnum in atis_test_sentences[:3]:
    parses = atis_parser.parse(sent)
    print(len(list(parses)), pnum)
# Out:
# 2085 2085
# 1380 1380
# 50 50

# %% [markdown]
# #### Exercise
# Parse the sentences from the exercise above using **ATIS_GRAMMAR**
# - try different parsers
# - output the number of parses each sentence yields

# %%
atis_parser = nltk.LeftCornerChartParser(atis_grammar) # Add your parser
for sent in test_sents:
    parses = atis_parser.parse(sent.split())
    print(len(list(parses)))
# Out:
# 3
# 3
# 1
# 1
# 1

# %%
atis_parser = nltk.RecursiveDescentParser(atis_grammar)
for sent in test_sents:
    parses = atis_parser.parse(sent.split())
    print(len(list(parses)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 4
#       2 for sent in test_sents:
#       3     parses = atis_parser.parse(sent.split())
# ----> 4     print(len(list(parses)))
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\recursivedescent.py:126, in RecursiveDescentParser._parse(self, remaining_text, tree, frontier)
#     124 # If the next element on the frontier is a tree, expand it.
#     125 elif isinstance(tree[frontier[0]], Tree):
# --> 126     yield from self._expand(remaining_text, tree, frontier)
#     128 # If the next element on the frontier is a token, match it.
#     129 else:
#     130     yield from self._match(remaining_text, tree, frontier)
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\recursivedescent.py:225, in RecursiveDescentParser._expand(self, remaining_text, tree, frontier, production)
#     223 if self._trace:
#     224     self._trace_expand(newtree, new_frontier, production)
# --> 225 yield from self._parse(
#     226     remaining_text, newtree, new_frontier + frontier[1:]
#     227 )
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\recursivedescent.py:126, in RecursiveDescentParser._parse(self, remaining_text, tree, frontier)
#     124 # If the next element on the frontier is a tree, expand it.
#     125 elif isinstance(tree[frontier[0]], Tree):
# --> 126     yield from self._expand(remaining_text, tree, frontier)
#     128 # If the next element on the frontier is a token, match it.
#     129 else:
#     130     yield from self._match(remaining_text, tree, frontier)
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\recursivedescent.py:225, in RecursiveDescentParser._expand(self, remaining_text, tree, frontier, production)
#     223 if self._trace:
#     224     self._trace_expand(newtree, new_frontier, production)
# --> 225 yield from self._parse(
#     226     remaining_text, newtree, new_frontier + frontier[1:]
#     227 )
#
#     [... skipping similar frames: RecursiveDescentParser._parse at line 126 (50 times), RecursiveDescentParser._expand at line 225 (49 times)]
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\recursivedescent.py:225, in RecursiveDescentParser._expand(self, remaining_text, tree, frontier, production)
#     223 if self._trace:
#     224     self._trace_expand(newtree, new_frontier, production)
# --> 225 yield from self._parse(
#     226     remaining_text, newtree, new_frontier + frontier[1:]
#     227 )
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\recursivedescent.py:126, in RecursiveDescentParser._parse(self, remaining_text, tree, frontier)
#     124 # If the next element on the frontier is a tree, expand it.
#     125 elif isinstance(tree[frontier[0]], Tree):
# --> 126     yield from self._expand(remaining_text, tree, frontier)
#     128 # If the next element on the frontier is a token, match it.
#     129 else:
#     130     yield from self._match(remaining_text, tree, frontier)
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\recursivedescent.py:213, in RecursiveDescentParser._expand(self, remaining_text, tree, frontier, production)
#     211 for production in productions:
#     212     lhs = production.lhs().symbol()
# --> 213     if lhs == tree[frontier[0]].label():
#     214         subtree = self._production_to_tree(production)
#     215         if frontier[0] == ():
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\tree\tree.py:162, in Tree.__getitem__(self, index)
#     160         return self[index[0]]
#     161     else:
# --> 162         return self[index[0]][index[1:]]
#     163 else:
#     164     raise TypeError(
#     165         "%s indices must be integers, not %s"
#     166         % (type(self).__name__, type(index).__name__)
#     167     )
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\tree\tree.py:162, in Tree.__getitem__(self, index)
#     160         return self[index[0]]
#     161     else:
# --> 162         return self[index[0]][index[1:]]
#     163 else:
#     164     raise TypeError(
#     165         "%s indices must be integers, not %s"
#     166         % (type(self).__name__, type(index).__name__)
#     167     )
#
#     [... skipping similar frames: Tree.__getitem__ at line 162 (19 times)]
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\tree\tree.py:162, in Tree.__getitem__(self, index)
#     160         return self[index[0]]
#     161     else:
# --> 162         return self[index[0]][index[1:]]
#     163 else:
#     164     raise TypeError(
#     165         "%s indices must be integers, not %s"
#     166         % (type(self).__name__, type(index).__name__)
#     167     )
#
# KeyboardInterrupt:

# %%
atis_parser = nltk.ShiftReduceParser(atis_grammar)
for sent in test_sents:
    parses = atis_parser.parse(sent.split())
    print(len(list(parses)))
# Out:
# Warning: ADJ_ABL -> only will never be used
# Warning: ADJ_AP -> last will never be used
# Warning: ADJ_AP -> less will never be used
# Warning: ADJ_AP -> less will never be used
# Warning: ADJ_AT -> the will never be used
# Warning: ADJ_AT -> a will never be used
# Warning: ADJ_AT -> a will never be used
# Warning: ADJ_AT -> no will never be used
# Warning: ADJ_CD -> seven will never be used
# Warning: ADJ_CD -> seven will never be used
# Warning: ADJ_CD -> three hundred will never be used
# Warning: ADJ_CD -> three hundred will never be used
# Warning: ADJ_CD -> three hundred will never be used
# Warning: ADJ_CD -> one will never be used
# Warning: ADJ_CD -> one will never be used
# Warning: ADJ_CD -> eighty three will never be used
# Warning: ADJ_CD -> eighty three will never be used
# Warning: ADJ_CD -> two hundred will never be used
# Warning: ADJ_CD -> two hundred will never be used
# Warning: ADJ_CD -> two hundred will never be used
# Warning: ADJ_CD -> eighty two will never be used
# Warning: ADJ_CD -> ten will never be used
# Warning: ADJ_CD -> fourteen will never be used
# Warning: ADJ_CD -> forty six will never be used
# Warning: ADJ_CD -> nine will never be used
# Warning: ADJ_CD -> nine will never be used
# Warning: ADJ_CD -> five will never be used
# Warning: ADJ_CD -> five will never be used
# Warning: ADJ_CD -> seventeen will never be used
# Warning: ADJ_CD -> eight will never be used
# Warning: ADJ_CD -> eight will never be used
# Warning: ADJ_CD -> six will never be used
# Warning: ADJ_CD -> six will never be used
# Warning: ADJ_CD -> forty seven will never be used
# Warning: ADJ_CD -> twelve will never be used
# Warning: ADJ_CD -> twelve will never be used
# Warning: ADJ_CD -> three will never be used
# Warning: ADJ_CD -> three will never be used
# Warning: ADJ_CD -> two will never be used
# Warning: ADJ_CD -> two will never be used
# Warning: ADJ_CD -> four will never be used
# Warning: ADJ_CD -> four will never be used
# Warning: ADJ_CD -> eleven will never be used
# Warning: ADJ_CD -> eleven will never be used
# Warning: ADJ_DT -> this will never be used
# Warning: ADJ_DT -> that will never be used
# Warning: ADJ_DT -> that will never be used
# Warning: ADJ_DT -> that will never be used
# Warning: ADJ_DTI -> zero will never be used
# Warning: ADJ_DTI -> zero will never be used
# Warning: ADJ_DTI -> any will never be used
# Warning: ADJ_DTI -> any will never be used
# Warning: ADJ_DTI -> either will never be used
# Warning: ADJ_DTI -> each will never be used
# Warning: ADJ_DTI -> some will never be used
# Warning: ADJ_DTI -> much will never be used
# Warning: ADJ_JJ -> select will never be used
# Warning: ADJ_JJ -> american will never be used
# Warning: ADJ_JJ -> downtown will never be used
# Warning: ADJ_JJ -> downtown will never be used
# Warning: ADJ_JJ -> pt347 will never be used
# Warning: ADJ_JJ -> so will never be used
# Warning: ADJ_JJ -> round will never be used
# Warning: ADJ_JJ -> round will never be used
# Warning: ADJ_JJ -> round will never be used
# Warning: ADJ_JJ -> pt60 will never be used
# Warning: ADJ_JJ -> pt60 will never be used
# Warning: ADJ_JJ -> northwest will never be used
# Warning: ADJ_JJ -> northwest will never be used
# Warning: ADJ_JJ -> northwest will never be used
# Warning: ADJ_JJ -> then will never be used
# Warning: ADJ_JJ -> then will never be used
# Warning: ADJ_JJ -> following will never be used
# Warning: ADJ_JJ -> following will never be used
# Warning: ADJ_JJ -> one way will never be used
# Warning: ADJ_JJ -> one way will never be used
# Warning: ADJ_JJ -> pt88 will never be used
# Warning: ADJ_JJ -> pt88 will never be used
# Warning: ADJ_JJ -> southwest will never be used
# Warning: ADJ_JJ -> pt117 will never be used
# Warning: ADJ_JJ -> continental will never be used
# Warning: ADJ_JJ -> possible will never be used
# Warning: ADJ_JJ -> pt194 will never be used
# Warning: ADJ_JJ -> c will never be used
# Warning: ADJ_JJ -> united will never be used
# Warning: ADJ_JJ -> united will never be used
# Warning: ADJ_JJ -> m will never be used
# Warning: ADJ_JJ -> n will never be used
# Warning: ADJ_JJ -> o will never be used
# Warning: ADJ_JJ -> after will never be used
# Warning: ADJ_JJ -> after will never be used
# Warning: ADJ_JJ -> s will never be used
# Warning: ADJ_JJ -> okay will never be used
# Warning: ADJ_JJ -> okay will never be used
# Warning: ADJ_JJ -> okay will never be used
# Warning: ADJ_JJ -> u will never be used
# Warning: ADJ_JJ -> w will never be used
# Warning: ADJ_JJ -> on will never be used
# Warning: ADJ_JJ -> early will never be used
# Warning: ADJ_JJ -> pt280 will never be used
# Warning: ADJ_JJ -> first class will never be used
# Warning: ADJ_JJ -> first class will never be used
# Warning: ADJ_JJ -> first class will never be used
# Warning: ADJ_JJ -> first class will never be used
# Warning: ADJ_JJR -> number will never be used
# Warning: ADJ_JJR -> number will never be used
# Warning: ADJ_JJR -> more will never be used
# Warning: ADJ_JJR -> pt56 will never be used
# Warning: ADJ_JJT -> least will never be used
# Warning: ADJ_JJT -> pt329 will never be used
# Warning: ADJ_JJT -> most will never be used
# Warning: ADJ_JJT -> most will never be used
# Warning: ADJ_JJT -> latest will never be used
# Warning: ADJ_JJT -> latest will never be used
# Warning: ADJ_JJT -> worst will never be used
# Warning: ADJ_OD -> first will never be used
# Warning: ADJ_WPS -> which will never be used
# Warning: ADJ_WPS -> what will never be used
# Warning: ADV_QL -> most will never be used
# Warning: ADV_QL -> the most will never be used
# Warning: ADV_QL -> any will never be used
# Warning: ADV_QL -> but will never be used
# Warning: ADV_QL -> a little bit will never be used
# Warning: ADV_QL -> a little bit will never be used
# Warning: ADV_QL -> a little bit will never be used
# Warning: ADV_QL -> at least will never be used
# Warning: ADV_QL -> a little will never be used
# Warning: ADV_QL -> a little will never be used
# Warning: ADV_QL -> a lot will never be used
# Warning: ADV_QL -> a lot will never be used
# Warning: ADV_QL -> that will never be used
# Warning: ADV_QL -> that will never be used
# Warning: ADV_QL -> way will never be used
# Warning: ADV_QL -> all will never be used
# Warning: ADV_QL -> all will never be used
# Warning: ADV_QL -> kind of will never be used
# Warning: ADV_RB -> downtown will never be used
# Warning: ADV_RB -> once again will never be used
# Warning: ADV_RB -> around will never be used
# Warning: ADV_RB -> northwest will never be used
# Warning: ADV_RB -> northwest will never be used
# Warning: ADV_RB -> then will never be used
# Warning: ADV_RB -> if possible will never be used
# Warning: ADV_RB -> if possible will never be used
# Warning: ADV_RB -> right now will never be used
# Warning: ADV_RB -> all right will never be used
# Warning: ADV_RB -> all right will never be used
# Warning: ADV_RB -> whether will never be used
# Warning: ADV_RB -> more than will never be used
# Warning: ADV_RB -> in between will never be used
# Warning: ADV_RB -> in between will never be used
# Warning: ADV_RB -> first thing will never be used
# Warning: ADV_RB -> less than will never be used
# Warning: ADV_RB -> less than will never be used
# Warning: ADV_RB -> less than will never be used
# Warning: ADV_RB -> to will never be used
# Warning: ADV_RB -> as soon as possible will never be used
# Warning: ADV_RB -> as soon as possible will never be used
# Warning: ADV_RB -> as soon as possible will never be used
# Warning: ADV_RB -> as soon as possible will never be used
# Warning: ADV_RB -> as well will never be used
# Warning: ADV_RB -> as well will never be used
# Warning: ADV_RB -> as well will never be used
# Warning: ADV_RB -> back will never be used
# Warning: ADV_RB -> back will never be used
# Warning: ADV_RB -> okay will never be used
# Warning: ADV_RB -> okay will never be used
# Warning: ADV_RB -> as will never be used
# Warning: ADV_RB -> as will never be used
# Warning: ADV_RB -> please will never be used
# Warning: ADV_RB -> early on will never be used
# Warning: ADV_RB -> about will never be used
# Warning: ADV_RB -> pt109 will never be used
# Warning: ADV_RB -> first class will never be used
# Warning: ADV_RBT -> latest will never be used
# Warning: AJP_AP -> how ADJ_AP PP_NNS will never be used
# Warning: AJP_AP -> how ADJ_AP PP_NNS will never be used
# Warning: AJP_AP -> how ADJ_AP will never be used
# Warning: AJP_AP -> ADJ_AP will never be used
# Warning: AJP_CC -> ADJ_CD CONJ_CC ADJ_CD CONJ_CC AJP_AP will never be used
# Warning: AJP_CC -> ADJ_CD CONJ_CC ADJ_CD CONJ_CC AJP_AP will never be used
# Warning: AJP_DTI -> how ADJ_DTI COMPCL_VB will never be used
# Warning: AJP_DTI -> how ADJ_DTI COMPCL_VB will never be used
# Warning: AJP_DTI -> how ADJ_DTI will never be used
# Warning: AJP_JJ -> ADJ_JJ PP_VBG will never be used
# Warning: AJP_JJ -> ADJ_JJ PP_NNS PP_NP will never be used
# Warning: AJP_JJ -> AVP_RB ADJ_JJ PP_NN will never be used
# Warning: AJP_JJR -> ADJ_JJR PP_CC will never be used
# Warning: AJP_JJR -> ADJ_JJR PP_ONS will never be used
# Warning: AJP_JJT -> ADJ_JJT PP_NN will never be used
# Warning: AJP_JJT -> ADJ_JJT PP_NP will never be used
# Warning: AVPNP_CC -> NP_NN CONJ_CC will never be used
# Warning: AVPNP_CC -> NP_NN CONJ_CC NP_NN will never be used
# Warning: AVPNP_CC -> NP_NN CONJ_CC NP_NN will never be used
# Warning: AVPNP_CC -> NP_NN CONJ_CC AVP_RB NP_NN will never be used
# Warning: AVPNP_CC -> NP_NN CONJ_CC NP_NNS will never be used
# Warning: AVPNP_CC -> NP_NN CONJ_CC NP_NNS will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP AVPNP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP AVPNP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP AVPNP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP AVPNP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP AVPNP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP AVPNP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP AVPNP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP AVPNP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP AVPNP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> AVP_RB NOUN_CD will never be used
# Warning: AVPNP_CD -> AVP_RB NOUN_CD will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD will never be used
# Warning: AVPNP_CD -> NOUN_CD will never be used
# Warning: AVPNP_CD -> ADJ_AT NOUN_CD will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_CD will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_CD will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_CD will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_CD will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_CC will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_CC will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_CD will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_CD will never be used
# Warning: AVPNP_CD -> AJP_JJ NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> AJP_JJ NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD AVPNP_CD will never be used
# Warning: AVPNP_CD -> NOUN_CD AVPNP_CD will never be used
# Warning: AVPNP_CD -> NOUN_CD AVPNP_CD will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NPS will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NPS will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NPS will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NPS will never be used
# Warning: AVPNP_CD -> ADJ_AT NOUN_CD AVPNP_CD will never be used
# Warning: AVPNP_CD -> AJP_JJ NOUN_CD will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_JJ will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_JJ will never be used
# Warning: AVPNP_CD -> AVP_RB NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> AVP_RB NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> AVP_RB NOUN_CD PP_NP PP_NP will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP PP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP PP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP PP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP PP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP PP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD PP_NP PP_NP PP_NN will never be used
# Warning: AVPNP_CD -> AVP_RB NOUN_CD PP_NN will never be used
# Warning: AVPNP_CD -> AVP_RB NOUN_CD PP_NN will never be used
# Warning: AVPNP_CD -> AVP_RB NOUN_CD PP_NN will never be used
# Warning: AVPNP_CD -> NOUN_CD RELCL_CC will never be used
# Warning: AVPNP_CD -> NOUN_CD RELCL_CC will never be used
# Warning: AVPNP_CD -> AVP_RB NOUN_CD PP_NP will never be used
# Warning: AVPNP_CD -> AVP_RB NOUN_CD PP_NP will never be used
# Warning: AVPNP_CD -> AJP_JJ NOUN_CD AVPNP_CD will never be used
# Warning: AVPNP_NN -> QUANP_DTI NOUN_NN will never be used
# Warning: AVPNP_NN -> QUANP_CD NOUN_NN PP_NP PP_NP will never be used
# Warning: AVPNP_NN -> QUANP_CD NOUN_NN PP_NP PP_NP will never be used
# Warning: AVPNP_NN -> QUANP_CD NOUN_NN PP_NP PP_NP will never be used
# Warning: AVPNP_NN -> ADJ_DT NOUN_NN will never be used
# Warning: AVPNP_NN -> ADJ_DT NOUN_NN will never be used
# Warning: AVPNP_NN -> QUANP_CD NOUN_NN PP_NN will never be used
# Warning: AVPNP_NN -> QUANP_CD NOUN_NN PP_NN will never be used
# Warning: AVPNP_NN -> ADJ_WPS NOUN_NN will never be used
# Warning: AVPNP_NN -> QUANP_CD NOUN_NN will never be used
# Warning: AVPNP_NN -> AJP_AP NOUN_NN will never be used
# Warning: AVPNP_NN -> ADJ_AT AJP_AP NOUN_NN will never be used
# Warning: AVPNP_NN -> AJP_JJ NOUN_NN will never be used
# Warning: AVPNP_NN -> AJP_JJ NOUN_NN will never be used
# Warning: AVPNP_NN -> QUANP_CD NOUN_NN PRPRTCL_VBG will never be used
# Warning: AVPNP_NN -> ADJ_AT AJP_JJ NOUN_NN will never be used
# Warning: AVPNP_NN -> ADJ_AT AJP_JJ NOUN_NN will never be used
# Warning: AVPNP_NN -> AVP_RB NOUN_NN PP_NP PP_NP will never be used
# Warning: AVPNP_NN -> ADJ_AT AJP_AP NOUN_NN RELCL_VB will never be used
# Warning: AVPNP_NN -> NP_NP NOUN_NN PP_NP will never be used
# Warning: AVPNP_NN -> NP_NP NOUN_NN PP_NP will never be used
# Warning: AVPNP_NN -> NP_NP NOUN_NN PP_NP will never be used
# Warning: AVPNP_NN -> NP_NP NOUN_NN PP_NP will never be used
# Warning: AVPNP_NN -> NP_NN NOUN_NN will never be used
# Warning: AVPNP_NN -> NP_NN NOUN_NN will never be used
# Warning: AVPNP_NN -> NP_NP NOUN_NN will never be used
# Warning: AVPNP_NN -> NP_NP NOUN_NN will never be used
# Warning: AVPNP_NN -> NP_NP NOUN_NN will never be used
# Warning: AVPNP_NN -> ADJ_AT NP_NP NOUN_NN will never be used
# Warning: AVPNP_NN -> NOUN_NN will never be used
# Warning: AVPNP_NN -> NP_NP NOUN_NN PRPRTCL_VBG will never be used
# Warning: AVPNP_NN -> NP_NP NOUN_NN PRPRTCL_VBG will never be used
# Warning: AVPNP_NN -> NP_NP NOUN_NN PRPRTCL_VBG will never be used
# Warning: AVPNP_NN -> NP_NP NOUN_NN PRPRTCL_VBG will never be used
# Warning: AVPNP_NN -> NP_NN NOUN_NN RELCL_VB will never be used
# Warning: AVPNP_NN -> NP_NN NOUN_NN RELCL_VB will never be used
# Warning: AVPNP_NN -> NP_NN NOUN_NN RELCL_VB will never be used
# Warning: AVPNP_NNS -> NOUN_NNS PP_NN will never be used
# Warning: AVPNP_NNS -> NOUN_NNS PP_NN will never be used
# Warning: AVPNP_NNS -> NOUN_NNS PP_NN will never be used
# Warning: AVPNP_NNS -> NP_NP NOUN_NNS will never be used
# Warning: AVPNP_NNS -> NP_NP NOUN_NNS will never be used
# Warning: AVPNP_NNS -> QUANP_AP NOUN_NNS will never be used
# Warning: AVPNP_NNS -> QUANP_ABN NOUN_NNS will never be used
# Warning: AVPNP_NNS -> NOUN_NNS PP_NN PP_NN will never be used
# Warning: AVPNP_NNS -> NOUN_NNS PP_NN PP_NN will never be used
# Warning: AVPNP_NNS -> NOUN_NNS PP_NN PP_NN will never be used
# Warning: AVPNP_NNS -> NOUN_NNS will never be used
# Warning: AVPNP_NNS -> AVP_RB NOUN_NNS AJP_JJ will never be used
# Warning: AVPNP_NNS -> ADJ_WPS NOUN_NNS will never be used
# Warning: AVPNP_NP -> ADJ_DT NOUN_NP PP_NPS PP_NP will never be used
# Warning: AVPNP_NP -> NOUN_NP AVPNP_CC AVP_RB will never be used
# Warning: AVPNP_NP -> NOUN_NP AVPNP_CC AVP_RB will never be used
# Warning: AVPNP_NP -> NOUN_NP AVPNP_CC AVP_RB will never be used
# Warning: AVPNP_NP -> NOUN_NP PRPRTCL_VBG will never be used
# Warning: AVPNP_NP -> NOUN_NP PRPRTCL_VBG will never be used
# Warning: AVPNP_NP -> NOUN_NP PRPRTCL_VBG will never be used
# Warning: AVPNP_NP -> NOUN_NP PRPRTCL_VBG will never be used
# Warning: AVPNP_NP -> AJP_AP NOUN_NP PRPRTCL_CC will never be used
# Warning: AVPNP_NP -> AJP_AP NOUN_NP PRPRTCL_CC will never be used
# Warning: AVPNP_NP -> AJP_AP NOUN_NP PP_NP PP_NPS will never be used
# Warning: AVPNP_NP -> AJP_AP NOUN_NP PP_NP PP_NPS will never be used
# Warning: AVPNP_NP -> NOUN_NP PP_NN will never be used
# Warning: AVPNP_NP -> NOUN_NP PP_NN will never be used
# Warning: AVPNP_NP -> NOUN_NP PP_NN will never be used
# Warning: AVPNP_NP -> NOUN_NP PP_NN will never be used
# Warning: AVPNP_NP -> NOUN_NP PP_NN will never be used
# Warning: AVPNP_NP -> NOUN_NP LABEL_NN will never be used
# Warning: AVPNP_NP -> NOUN_NP LABEL_NN will never be used
# Warning: AVPNP_NP -> NOUN_NP LABEL_NN will never be used
# Warning: AVPNP_NP -> AJP_AP NOUN_NP will never be used
# Warning: AVPNP_NP -> AJP_AP NOUN_NP RELCL_MD will never be used
# Warning: AVPNP_NP -> AJP_AP NOUN_NP RELCL_VBZ will never be used
# Warning: AVPNP_NP -> AJP_JJ NOUN_NP will never be used
# Warning: AVPNP_NP -> NOUN_NP will never be used
# Warning: AVPNP_NP -> NOUN_NP will never be used
# Warning: AVPNP_NP -> AJP_AP NOUN_NP PRPRTCL_VBG will never be used
# Warning: AVP_RBR -> pt56 SUBCL_BER will never be used
# Warning: AVP_RBR -> pt56 PP_WPS will never be used
# Warning: COMPCL_BEZ -> NP_NN VERB_BEZ NP_PPS will never be used
# Warning: COMPCL_BEZ -> NP_NN VERB_BEZ NP_PPS will never be used
# Warning: COMPCL_BEZ -> NP_NN VERB_BEZ NP_PPS will never be used
# Warning: COMPCL_BEZ -> NP_NN VERB_BEZ NP_CD will never be used
# Warning: COMPCL_BEZ -> NP_NN VERB_BEZ NP_CD will never be used
# Warning: COMPCL_DOZ -> NP_NN VERB_DOZ NP_WPS will never be used
# Warning: COMPCL_HV -> NP_NNS pt_verb_do NP_PPSS VERB_HV RELCL_DO will never be used
# Warning: COMPCL_HV -> NP_NNS pt_verb_do NP_PPSS VERB_HV RELCL_DO will never be used
# Warning: COMPCL_HV -> NP_PPSS VERB_HV NP_VBG will never be used
# Warning: COMPCL_HV -> NP_PPSS VERB_HV NP_VBG will never be used
# Warning: COMPCL_HV -> NP_PPSS VERB_HV NP_VBG will never be used
# Warning: COMPCL_MD -> NP_PPSS VERB_MD NP_NN will never be used
# Warning: COMPCL_MD -> NP_PPSS VERB_MD NP_NN will never be used
# Warning: COMPCL_VB -> NP_NN VERB_VB NP_CD will never be used
# Warning: COMPCL_VB -> NP_DTS VERB_VB NP_DTS will never be used
# Warning: COMPCL_VB -> NP_NNS VERB_VB NP_DTS will never be used
# Warning: COMPCL_VB -> NP_NNS VERB_VB NP_DTS will never be used
# Warning: COMPCL_VB -> NP_PPS VERB_VB PRPRTCL_VBG will never be used
# Warning: COMPCL_VB -> NP_PPSS VERB_VB NP_NN AVP_RB will never be used
# Warning: COMPCL_VB -> NP_PPSS VERB_VB NP_NN AVP_RB will never be used
# Warning: COMPCL_VB -> NP_JJ VERB_VB NP_NN PP_NP will never be used
# Warning: COMPCL_VB -> NP_NNS VERB_VB NP_NP will never be used
# Warning: COMPCL_VB -> NP_NNS VERB_VB NP_NP will never be used
# Warning: COMPCL_VB -> NP_NNS VERB_VB NP_NNS will never be used
# Warning: COMPCL_VB -> NP_NNS VERB_VB NP_NNS will never be used
# Warning: COMPCL_VBZ -> NP_DTS VERB_VBZ PP_NP PP_NP AVPNP_CD NP_VBG will never be used
# Warning: COMPCL_VBZ -> NP_PPO VERB_VBZ NP_WPS will never be used
# Warning: COMPCL_VBZ -> NP_NN VERB_VBZ AVP_RB will never be used
# Warning: COMPCL_VBZ -> NP_NN VERB_VBZ AVP_RB will never be used
# Warning: COMPCL_VBZ -> NP_DT VERB_VBZ PP_NP PP_NPS PP_NP NP_NNS will never be used
# Warning: COMPCL_VBZ -> NP_PPO VERB_VBZ PP_NP NP_PPSS NP_NN PP_NPS will never be used
# Warning: COMPCL_VBZ -> NP_NN VERB_VBZ NP_NNS will never be used
# Warning: COMPCL_VBZ -> NP_NN VERB_VBZ NP_NNS will never be used
# Warning: COMPCL_VBZ -> NP_NN VERB_VBZ AVP_RB NP_NP will never be used
# Warning: COMPCL_VBZ -> NP_NN VERB_VBZ AVP_RB NP_NP will never be used
# Warning: COMPCL_VBZ -> NP_JJT VERB_VBZ NP_NN will never be used
# Warning: CONJ_CC -> less than will never be used
# Warning: CONJ_CC -> less than will never be used
# Warning: CONJ_CS -> that will never be used
# Warning: CONJ_CS -> after will never be used
# Warning: CONJ_CS -> as will never be used
# Warning: CONJ_CS -> as soon as will never be used
# Warning: CONJ_CS -> pt5 will never be used
# Warning: CONJ_CS -> than will never be used
# Warning: CONJ_CS -> if will never be used
# Warning: DECL_BE -> NP_NN VERB_MD pt_verb_be PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BE -> NP_NN VERB_MD pt_verb_be PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BE -> NP_NN VERB_MD pt_verb_be NP_NP pt_char_per will never be used
# Warning: DECL_BE -> NP_NN VERB_MD pt_verb_be PP_NP pt_char_per will never be used
# Warning: DECL_BE -> NP_NN VERB_MD pt_verb_be PP_NP pt_char_per will never be used
# Warning: DECL_BE -> NP_NN VERB_MD pt_verb_be NP_NP AVPNP_NP pt_char_per will never be used
# Warning: DECL_BE -> NP_PPS VERB_MD pt_verb_be NP_NN pt_char_per will never be used
# Warning: DECL_BE -> NP_DT VERB_MD NP_NN pt_verb_be PP_NN pt_char_per will never be used
# Warning: DECL_BEDZ -> NREL_VBD pt_verb_bedz NP_NN PP_NN pt_char_per will never be used
# Warning: DECL_BEM -> NP_PPSS pt_verb_bem PP_NN pt_char_per will never be used
# Warning: DECL_BEM -> NP_PPSS pt_verb_bem AJP_JJ pt_char_per will never be used
# Warning: DECL_BEM -> NP_PPSS pt_verb_bem AJP_JJ pt_char_per will never be used
# Warning: DECL_BEM -> NP_PPSS pt_verb_bem AJP_JJ AVP_RB pt_char_per will never be used
# Warning: DECL_BEM -> NP_PPSS pt_verb_bem AJP_JJ AVP_RB pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB PP_NP PP_NPS pt_char_per will never be used
# Warning: DECL_BER -> NP_NN pt_verb_ber PP_NNS NP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber NP_DTS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber PP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber NP_NPS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber PP_NP PP_NP AVPNP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber PP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber NP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber NP_CC pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB PP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_DT NP_NNS pt_verb_ber AVP_RB PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT NP_NNS pt_verb_ber AVP_RB PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS AVPNP_CD AVPNP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS AVPNP_CD AVPNP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS AVPNP_CD AVPNP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS AVP_RB PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS AVP_RB PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS AVP_RB PP_NP pt_char_per will never be used
# Warning: DECL_BER -> pt_verb_ber AVP_RB NP_NNS PP_NN PP_NP PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_CC pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_CC pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_CC pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NN PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NN PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NN PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB PP_NP PP_NP PP_NN pt_char_per will never be used
# Warning: DECL_BER -> pt_verb_ber AVP_RB NP_NNS PP_NP PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS NP_VBG pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS NP_VBG pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS NP_VBG pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB PP_NP PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB PP_NP PP_NP AVPNP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_WPS pt_verb_ber PP_CC PP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_CC pt_verb_ber PP_NP PP_NP PP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber PP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ AVPNP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ AVPNP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_NN pt_verb_ber NP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ PP_NP PP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ PP_NP PP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_WPS pt_verb_ber PP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_WPS pt_verb_ber PP_NNS pt_char_per will never be used
# Warning: DECL_BER -> pt_verb_ber AVP_RB NP_NNS AVPNP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB pt_char_per will never be used
# Warning: DECL_BER -> pt_verb_ber AVP_RB NP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NNS PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NNS PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NNS PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> pt_verb_ber AVP_RB NP_NNS AJP_JJ pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber NP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber NP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber PP_NP PP_NPS AVPNP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS AVPNP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS AVPNP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS AVPNP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber PP_NP PP_NP PP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber PP_NP PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_WPS pt_verb_ber AJP_JJ pt_char_per will never be used
# Warning: DECL_BER -> NP_WPS pt_verb_ber AJP_JJ pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber PP_NP PP_NP AVPNP_NN PP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_WPS pt_verb_ber NP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_WPS pt_verb_ber NP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_NN pt_verb_ber AVP_RB NP_CC PP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_CC PP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_CC PP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_CC PP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_PPSS pt_char_per will never be used
# Warning: DECL_BER -> NP_ONS pt_verb_ber NP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ PP_NN PP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ PP_NN PP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AJP_JJ PP_NN PP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_NN pt_verb_ber NP_CC pt_char_per will never be used
# Warning: DECL_BER -> NP_NP NP_NNS pt_verb_ber PP_NP PP_NP PP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_WPS pt_verb_ber NP_JJT pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_NN pt_verb_ber NP_DTS pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS pt_char_per will never be used
# Warning: DECL_BER -> pt_verb_ber AVP_RB NP_NNS PP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB PP_NN pt_char_per will never be used
# Warning: DECL_BER -> pt_verb_ber AVP_RB NP_NNS PP_NP pt_char_per will never be used
# Warning: DECL_BER -> NP_WPS pt_verb_ber NP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_WPS pt_verb_ber NP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB PP_NP pt_char_per will never be used
# Warning: DECL_BER -> pt_verb_ber AVP_RB NP_NNS NP_NN PP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB PP_CC PP_NN pt_char_per will never be used
# Warning: DECL_BER -> NP_NN pt_verb_ber PP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_NN NP_DTS pt_verb_ber AVP_RB NP_NNS pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB PP_NP PP_NP AVPNP_NP PP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NP AVPNP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NP AVPNP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_DT pt_verb_ber NP_NNS PP_NP AVPNP_CD pt_char_per will never be used
# Warning: DECL_BER -> NP_NNS pt_verb_ber AVP_RB PP_CC pt_char_per will never be used
# Warning: DECL_BER -> pt_verb_ber AVP_RB NP_NNS PP_CD pt_char_per will never be used
# Warning: DECL_BER -> pt_verb_ber AJP_JJ pt_char_per will never be used
# Warning: DECL_BEZ -> VERB_BEZ AVP_RB NP_NN PP_NN PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> VERB_BEZ NP_DT NP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> VERB_BEZ AVP_RB NP_NN PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> VERB_BEZ AVP_RB NP_NN PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_CD VERB_BEZ AJP_JJ pt_char_per will never be used
# Warning: DECL_BEZ -> VERB_BEZ AVP_RB NP_NN AVPNP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> VERB_BEZ AVP_RB NP_NN PP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ AJP_JJT pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ AJP_JJT pt_char_per will never be used
# Warning: DECL_BEZ -> NP_WPS VERB_BEZ NP_JJT pt_char_per will never be used
# Warning: DECL_BEZ -> VERB_BEZ AVP_RB NP_NN AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> VERB_BEZ AVP_RB NP_NN AJP_JJ pt_char_per will never be used
# Warning: DECL_BEZ -> NP_WPS VERB_BEZ NP_NNS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_WPS VERB_BEZ NP_NNS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NN PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NN PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NN PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NN PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NN PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN AVPNP_CD AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN AVPNP_CD AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN AVPNP_CD AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN AVPNP_CD AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_NN AVP_RB pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_NN AVP_RB pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_NP PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_NP PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_NP PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_WPS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_WPS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN SUBCL_VB pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN SUBCL_VB pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN SUBCL_VB pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN SUBCL_VB pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ AJP_JJ PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ AJP_JJ PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ AVP_RB NP_NN PP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ AVP_RB NP_NN PP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> VERB_BEZ AVP_RB NP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> VERB_BEZ AVP_RB NP_NN AJP_JJ PP_NN PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_WPS VERB_BEZ AJP_JJR pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_JJT pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_JJT pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_JJT pt_char_per will never be used
# Warning: DECL_BEZ -> NP_CD VERB_BEZ NP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_NN AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_NN AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> VERB_BEZ AVP_RB NP_NN AJP_JJ PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NNS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NNS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_WPS VERB_BEZ AJP_AP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_WPS VERB_BEZ PP_NNS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ PP_NP PP_NPS AVPNP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ PP_NP PP_NPS AVPNP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_CD VERB_BEZ NP_CC pt_char_per will never be used
# Warning: DECL_BEZ -> NP_WPS VERB_BEZ NP_JJ pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN AVP_RB pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN AVP_RB pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN AVP_RB pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN AVP_RB pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_PPS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_PPS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_PPS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ COMPCL_VB pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ COMPCL_VB pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NNS AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NNS AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_DT pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ NP_DT pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ PP_NP PP_NP PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ PP_NP PP_NP PP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NNS VERB_BEZ AJP_JJT pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NNS VERB_BEZ AJP_JJT pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ PP_NP PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ PP_NP PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_BEZ -> NP_WPS VERB_BEZ NP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_WPS VERB_BEZ NP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ PP_NP PP_NP AVPNP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ PP_NP PP_NP AVPNP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NP VERB_BEZ NP_NN pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_CC pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_CC pt_char_per will never be used
# Warning: DECL_BEZ -> NP_WPS VERB_BEZ NP_CC pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NPS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NPS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NPS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN PP_NPS pt_char_per will never be used
# Warning: DECL_BEZ -> NP_WPS VERB_BEZ AJP_JJ pt_char_per will never be used
# Warning: DECL_BEZ -> NP_WPS VERB_BEZ AJP_JJ pt_char_per will never be used
# Warning: DECL_BEZ -> NP_CD VERB_BEZ AJP_JJT pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ AJP_JJ pt_char_per will never be used
# Warning: DECL_BEZ -> NP_NN VERB_BEZ AJP_JJ pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN IJ_UH AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN IJ_UH AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN IJ_UH AVPNP_CD pt_char_per will never be used
# Warning: DECL_BEZ -> NP_DT VERB_BEZ NP_NN IJ_UH AVPNP_CD pt_char_per will never be used
# Warning: DECL_CC -> NP_PPSS VP_MD CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NREL_BER VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_NNS VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_NNS VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_NNS VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_NN VP_VBZ CONJ_CC VP_VBZ pt_char_per will never be used
# Warning: DECL_CC -> VP_VBG CONJ_CC VP_VBG pt_char_per will never be used
# Warning: DECL_CC -> NP_NP VP_VBZ CONJ_CC VP_VBZ pt_char_per will never be used
# Warning: DECL_CC -> NP_PPS VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NREL_BEZ VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_NNS VP_VB CONJ_CC VP_HV pt_char_per will never be used
# Warning: DECL_CC -> NP_NN VP_VBZ CONJ_CC VP_HVZ pt_char_per will never be used
# Warning: DECL_CC -> NP_CC VP_VBZ CONJ_CC VP_VBZ pt_char_per will never be used
# Warning: DECL_CC -> NP_WPS VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_WPS VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_NN VERB_MD VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_NN VERB_MD VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_NN VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_CD VP_VBZ CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_PPSS VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_PPSS VP_VB CONJ_CC VP_VB pt_char_per will never be used
# Warning: DECL_CC -> NP_NNS pt_verb_ber VP_VBG CONJ_CC VP_VBG pt_char_per will never be used
# Warning: DECL_DOZ -> NP_DT VERB_DOZ NP_NN pt_char_per will never be used
# Warning: DECL_DOZ -> NP_DT VERB_DOZ NP_NN pt_char_per will never be used
# Warning: DECL_DOZ -> NP_NNS VERB_DOZ NP_NN PP_NN pt_char_per will never be used
# Warning: DECL_DOZ -> NP_DT VERB_DOZ NP_NP pt_char_per will never be used
# Warning: DECL_DOZ -> NP_DT VERB_DOZ NP_NP pt_char_per will never be used
# Warning: DECL_DOZ -> NP_DT VERB_DOZ pt_char_per will never be used
# Warning: DECL_DOZ -> NP_DT VERB_DOZ NP_NP NP_NN pt_char_per will never be used
# Warning: DECL_DOZ -> NP_DT VERB_DOZ NP_NP NP_NN pt_char_per will never be used
# Warning: DECL_DOZ -> NP_NN NP_NN VERB_DOZ NP_PPS NP_NN pt_char_per will never be used
# Warning: DECL_HV -> NP_PPSS VERB_HV NP_NNS pt_char_per will never be used
# Warning: DECL_HV -> NP_PPSS VERB_HV NP_NNS pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS pt_verb_do NP_PPSS VERB_HV PP_NP PP_NP RELCL_VB pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS pt_verb_do NP_PPSS VERB_HV PP_NP PP_NP RELCL_VB pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS VERB_HV NP_NNS pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS VERB_DOZ NP_NN VERB_HV AVP_RB pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS VERB_DOZ NP_NN VERB_HV PP_NN AVPNP_NN pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS VERB_DOZ NP_NP VERB_HV AVP_RB pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS pt_verb_do NP_NNS VERB_HV pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS pt_verb_do NP_NNS VERB_HV pt_char_per will never be used
# Warning: DECL_HV -> NP_WPS pt_verb_do AVP_RB VERB_HV NP_NNS pt_char_per will never be used
# Warning: DECL_HV -> NP_WPS VERB_HV NP_NNS AVPNP_NN pt_char_per will never be used
# Warning: DECL_HV -> NP_WPS VERB_HV NP_NNS AVPNP_NN pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS VERB_HV NP_NN pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS VERB_HV NP_NN pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS pt_verb_do NP_PPSS VERB_HV PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS pt_verb_do NP_PPSS VERB_HV PP_NP PP_NP pt_char_per will never be used
# Warning: DECL_HV -> NP_WPS VERB_HV NP_NN pt_char_per will never be used
# Warning: DECL_HV -> NP_WPS VERB_HV NP_NN pt_char_per will never be used
# Warning: DECL_HV -> NREL_BEZ NP_PPSS VERB_HV pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS pt_verb_do NP_PPSS VERB_HV INFCL_VB pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS pt_verb_do NP_PPSS VERB_HV INFCL_VB pt_char_per will never be used
# Warning: DECL_HV -> NP_NNS VERB_DOZ NP_NP VERB_HV PP_NN AVP_RB pt_char_per will never be used
# Warning: DECL_HV -> NP_PPSS VERB_HV NP_NN pt_char_per will never be used
# ...
# Warning: RELCL_HVZ -> NP_WPS NP_NP pt_verb_hvz will never be used
# Warning: RELCL_HVZ -> NP_WPS pt_verb_hvz NP_NNS will never be used
# Warning: RELCL_MD -> NP_PPS VERB_MD INFCL_BE will never be used
# Warning: RELCL_MD -> NP_PPSS VERB_MD VERB_MD INFCL_VB will never be used
# Warning: RELCL_MD -> NP_PPSS VERB_MD VERB_MD INFCL_VB will never be used
# Warning: RELCL_MD -> NP_PPSS VERB_MD INFCL_VB will never be used
# Warning: RELCL_MD -> NP_PPSS VERB_MD INFCL_VB will never be used
# Warning: RELCL_MD -> NP_PPSS AVP_RB VERB_MD INFCL_VB will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_CD will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_CD will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_CD will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_MD VERB_VB NP_NN will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_MD VERB_VB NP_NN will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_MD VERB_VB NP_NN will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NP PP_NN PP_NNS will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NP PP_NN PP_NNS will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NP PP_NN PP_NNS will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NP PP_NN PP_NNS will never be used
# Warning: RELCL_VB -> NP_WPS VERB_MD VERB_VB PP_CD will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NPS PP_NP PP_NP will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NPS PP_NP PP_NP will never be used
# Warning: RELCL_VB -> NP_WPS NP_NNS VERB_VB will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_VB INFCL_VB will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_VB INFCL_VB will never be used
# Warning: RELCL_VB -> NP_NN VERB_MD AVP_RB VERB_VB NP_NN will never be used
# Warning: RELCL_VB -> NP_WPS pt_verb_do AVP_RB VERB_VB PP_NP will never be used
# Warning: RELCL_VB -> NP_NNS VERB_VB PREP_IN will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NPS will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NPS will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NPS will never be used
# Warning: RELCL_VB -> NP_NN VERB_MD VERB_VB PREP_IN will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NP AVP_RB will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NP AVP_RB will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NP AVP_RB will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NP AVP_RB will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_MD VERB_VB INFCL_HV will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_MD VERB_VB INFCL_HV will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_MD VERB_VB INFCL_HV will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB AVP_RB PP_NP will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB AVP_RB PP_NP will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NN ADJ_ABL will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NN ADJ_ABL will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NN ADJ_ABL will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NN will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NN will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NN will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NN will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NP will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NP will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB AVP_RB PP_CD will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB AVP_RB PP_CD will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_CC will never be used
# Warning: RELCL_VB -> NP_NP VERB_VB will never be used
# Warning: RELCL_VB -> NP_CC VERB_VB NP_NN will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_CC will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_CD will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_DTS will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_MD VERB_VB will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NNS will never be used
# Warning: RELCL_VB -> NP_CD VERB_VB will never be used
# Warning: RELCL_VB -> NP_NP IJ_UH VERB_VB will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NPS PP_CD will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NP PP_CD AJP_CC will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NP PP_CD AJP_CC will never be used
# Warning: RELCL_VB -> NP_WPS VERB_MD VERB_VB INFCL_VB will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB AVPNP_NP will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_MD VERB_VB AVP_RB will never be used
# Warning: RELCL_VB -> NP_WPS NP_CC VERB_VB INFCL_VB will never be used
# Warning: RELCL_VB -> NP_VBG VERB_VB NP_CD will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PREP_IN PP_NP will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB AVPNP_CD will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NNS will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_MD VERB_VB INFCL_VB will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_MD VERB_VB INFCL_VB will never be used
# Warning: RELCL_VB -> NP_WPS AVP_RB VERB_VB NP_NN will never be used
# Warning: RELCL_VB -> NP_VBG VERB_VB ADJ_CD AVP_RB will never be used
# Warning: RELCL_VB -> NP_WPS VERB_MD VERB_VB NP_PPO PP_NP AVP_CC will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_DT will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NP PP_NP PP_NP will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NP PP_NN will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NP PP_NN will never be used
# Warning: RELCL_VB -> NP_NNS VERB_VB NP_NP PP_CD will never be used
# Warning: RELCL_VB -> NP_PPSS VERB_VB COMPCL_DOZ will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NP PP_NN will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NP PP_NP will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NP PP_NP will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NN will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NP PP_VBG will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NP PP_VBG will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NP will never be used
# Warning: RELCL_VB -> NP_DT VERB_VB PP_NP will never be used
# Warning: RELCL_VB -> NP_NN VERB_MD VERB_VB PP_NN will never be used
# Warning: RELCL_VB -> NP_ONS VERB_VB PP_CD will never be used
# Warning: RELCL_VB -> NP_WPS NP_PPSS VERB_MD VERB_VB PP_NP will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_NP PP_CD will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB NP_NP PP_CD will never be used
# Warning: RELCL_VB -> NP_WPS VERB_VB PP_NP PP_CC will never be used
# Warning: RELCL_VBD -> NP_WPS VERB_VBD PP_DT will never be used
# Warning: RELCL_VBD -> NP_WPS NP_PPSS AVP_QL VERB_VBD NP_PPO NP_NN will never be used
# Warning: RELCL_VBD -> NP_PPSS AVP_QL VERB_VBD NP_PPO will never be used
# Warning: RELCL_VBG -> NP_WPS NP_NP VERB_MD pt_verb_be VERB_VBG PREP_IN PP_NP will never be used
# Warning: RELCL_VBG -> NP_PPSS pt_verb_bem VERB_VBG PREP_IN will never be used
# Warning: RELCL_VBG -> NP_WPS pt_verb_ber VERB_VBG PP_CD will never be used
# Warning: RELCL_VBG -> NP_NNS VERB_MD pt_verb_be VERB_VBG PP_NP will never be used
# Warning: RELCL_VBG -> NP_WPS VERB_MD pt_verb_be VERB_VBG NP_NNS will never be used
# Warning: RELCL_VBN -> NP_WPS NP_NN VERB_BEZ VERB_VBN PREP_IN will never be used
# Warning: RELCL_VBN -> NP_NN VERB_BEZ VERB_VBN PREP_IN will never be used
# Warning: RELCL_VBN -> NP_WPS pt_verb_ber VERB_VBN PP_NNS will never be used
# Warning: RELCL_VBN -> NP_NNS VERB_BEZ VERB_VBN PREP_IN will never be used
# Warning: RELCL_VBN -> NP_WPS VERB_BEZ VERB_VBN PP_NN will never be used
# Warning: RELCL_VBZ -> NP_NP VERB_VBZ PP_CC will never be used
# Warning: RELCL_VBZ -> NP_NP VERB_VBZ PP_CC will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NNS will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NNS will never be used
# Warning: RELCL_VBZ -> NP_WPS NP_NNS VERB_VBZ will never be used
# Warning: RELCL_VBZ -> NP_WPS NP_NPS VERB_VBZ will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP AVP_RB NP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP AVP_RB NP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP AVP_RB NP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NPS PP_CD will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NPS PP_CD will never be used
# Warning: RELCL_VBZ -> NP_WPS NP_NP VERB_VBZ will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NP PP_DTS will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NP PP_DTS will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NP PP_DTS will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN PP_NPS will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN PP_NPS will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN PP_NPS will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PREP_IN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PREP_IN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN NREL_BEZ will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN NREL_BEZ will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN NREL_BEZ will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ AVPNP_CD will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ AVPNP_CD will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ AVP_RBR will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ AVP_RBR will never be used
# Warning: RELCL_VBZ -> NP_NP VERB_VBZ PREP_IN will never be used
# Warning: RELCL_VBZ -> NP_NP VERB_VBZ PREP_IN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NP PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NP PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NP PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NP PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NN PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ AVP_RB will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ AVP_RB will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NN will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ AVP_RB NP_CD will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ AVP_RB NP_CD will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ will never be used
# Warning: RELCL_VBZ -> NP_NN VERB_VBZ will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_CC will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP PP_CD will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ NP_CD will never be used
# Warning: RELCL_VBZ -> NP_NP VERB_VBZ will never be used
# Warning: RELCL_VBZ -> NP_NN VERB_VBZ INFCL_VB will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_CC will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_CD will never be used
# Warning: RELCL_VBZ -> NP_WPS VERB_VBZ PP_NP AVPNP_CD will never be used
# Warning: SUBCL_VB -> CONJ_CS NP_PPSS VERB_VB NP_CC NP_NN will never be used
# Warning: SUBCL_VB -> CONJ_CS NP_PPSS VERB_VB PP_NP will never be used
# Warning: VERB_BEZ -> _s will never be used
# Warning: VERB_HVD -> _d will never be used
# Warning: VERB_VBD -> pt286 will never be used
# Warning: VP_BER -> NP_DT pt_verb_ber NP_NNS PP_NN AVP_RB will never be used
# Warning: VP_VB -> VERB_VB PP_NP AVP_RB PP_CD will never be used
# Warning: VP_VB -> VERB_VB PP_NP AVP_RB PP_CD will never be used
# Warning: VP_VB -> VERB_VB PP_NP PP_NP PP_CD will never be used
# Warning: VP_VB -> VERB_VB PP_NP PP_NP PP_CD will never be used
# Warning: VP_VB -> VERB_VB PP_NP PP_NP PP_CD will never be used
# Warning: VP_VB -> VERB_VB PP_CD AVPNP_NP PP_NP will never be used
# Warning: VP_VB -> VERB_VB PP_NP PP_DTS will never be used
# Warning: VP_VB -> VERB_VB PP_NP PP_NPS PP_NP will never be used
# Warning: VP_VB -> VERB_VB PP_NP PP_CD NP_PPS will never be used
# Warning: VP_VB -> VERB_VB PP_NP PP_CD NP_PPS will never be used
# Warning: VP_VB -> VERB_VB AVP_RB PP_NP will never be used
# Warning: VP_VB -> VERB_VB AVP_RB PP_CD will never be used
# Warning: VP_VB -> VERB_VB PP_NP AVPNP_CD will never be used
# Warning: VP_VB -> VERB_VB NP_NP PP_NN will never be used
# Warning: VP_VB -> VERB_VB NP_NP PP_NP will never be used
# Warning: VP_VB -> VERB_VB PP_NP PP_NN will never be used
# Warning: VP_VB -> VERB_VB PP_NP PP_NP will never be used
# Warning: VP_VB -> VERB_VB PP_NP SUBCL_BE will never be used
# Warning: VP_VB -> NP_PPSS VERB_VB NP_NNS AVP_RB will never be used
# Warning: VP_VB -> VERB_VB NP_NNS PP_NP PP_NP PP_NP will never be used
# Warning: VP_VBG -> VERB_VBG PP_NP PP_NP PP_NN will never be used
# Warning: VP_VBG -> VERB_VBG PP_NP PP_NP PP_NN will never be used
# Warning: VP_VBG -> VERB_VBG PP_NP PP_NN will never be used
# Warning: VP_VBG -> VERB_VBG PP_NP PP_NN will never be used
# Warning: VP_VBG -> VERB_VBG NP_NP PP_NP will never be used
# Warning: VP_VBG -> VERB_VBG NP_NP PP_NP will never be used
# Warning: VP_VBG -> VERB_VBG NP_NN will never be used
# Warning: VP_VBG -> VERB_VBG PP_NP PP_VBG will never be used
# Warning: VP_VBG -> VERB_VBG PP_NP PP_VBG will never be used
# Warning: VP_VBG -> VERB_VBG PP_NN will never be used
# Warning: VP_VBG -> VERB_VBG NP_NP will never be used
# Warning: VP_VBG -> VERB_VBG PP_NPS PREP_IN will never be used
# Warning: VP_VBG -> VERB_VBG PP_NP will never be used
# Warning: VP_VBG -> VERB_VBG PP_NP AVPNP_NP will never be used
# Warning: VP_VBG -> NP_PPSS pt_verb_bem VERB_VBG PP_NP PP_NP will never be used
# Warning: VP_VBZ -> VERB_VBZ PP_CC PP_NN will never be used
# Warning: VP_VBZ -> VERB_VBZ AVP_RB PP_CD will never be used
# Warning: VP_VBZ -> VERB_VBZ AVPNP_NN will never be used
# Warning: VP_VBZ -> VERB_VBZ PP_NP PP_CD will never be used
# Warning: VP_VBZ -> VERB_VBZ PP_NP PP_DTS will never be used
# Warning: VP_VBZ -> VERB_VBZ PP_NP AVPNP_CD will never be used
# Warning: VP_VBZ -> VERB_VBZ NP_NPS PP_NN will never be used
# Warning: VP_VBZ -> VERB_VBZ NP_NP PP_NN will never be used
# Warning: VP_VBZ -> VERB_VBZ PP_NP PP_NP will never be used
# 0
# 0
# 0
# 0
# 0

# %%
atis_parser = nltk.ChartParser(atis_grammar)
for sent in test_sents:
    parses = atis_parser.parse(sent.split())
    print(len(list(parses)))
# Out:
# 3
# 3
# 1
# 1
# 1

# %% [markdown]
# ## 3. Probabilistic Context Free Grammars (PCFG)
#
# PCFGs are very similar to CFGs - they just have an additional probability for each production.
#
# For a given left-hand-side non-terminal, the sum of the probabilities must be 1.0!

# %%
weighted_rules = [
    'S -> NP VP [1.0]',
    'NP -> Det N [0.6]',
    'NP -> Det N PP [0.3]',
    'NP -> PRON [0.1]',
    'VP -> V NP [0.7]',
    'VP -> V NP PP [0.3]',
    'PP -> P NP [1.0]',
    'Det -> "the" [0.5]',
    'Det -> "a" [0.5]',
    'N -> "man" [0.5]',
    'N -> "telescope" [0.5]',
    'PRON -> "I" [1.0]',
    'V -> "saw" [1.0]',
    'P -> "with" [1.0]'   
]

toy_grammar = nltk.PCFG.fromstring(weighted_rules)

print(toy_grammar)
# Out:
# Grammar with 14 productions (start state = S)
#     S -> NP VP [1.0]
#     NP -> Det N [0.6]
#     NP -> Det N PP [0.3]
#     NP -> PRON [0.1]
#     VP -> V NP [0.7]
#     VP -> V NP PP [0.3]
#     PP -> P NP [1.0]
#     Det -> 'the' [0.5]
#     Det -> 'a' [0.5]
#     N -> 'man' [0.5]
#     N -> 'telescope' [0.5]
#     PRON -> 'I' [1.0]
#     V -> 'saw' [1.0]
#     P -> 'with' [1.0]

# %% [markdown]
# On top of right-hand side and left-hand side, probabilistic rules have probabilities.

# %%
rule = toy_grammar.productions()[2]
print(rule.lhs())
print(rule.rhs())
print(rule.prob())
# Out:
# NP
# (Det, N, PP)
# 0.3

# %% [markdown]
# ### 3.1. Learning Grammars from a Treebank
#
# The most important method consists of inducing a PCFG from trees in a treebank (`induce_pcfg()`).
#
# NLTK provides portion of Penn Treebank corpus, which we can utilize to induce rules.

# %%
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\adnan\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# True

# %% [markdown]
# Production rules can be extracted using `productions()` method iterating over parsed sentences in the corpus.

# %%
from nltk.corpus import treebank

print(treebank)

productions = []

# let's keep it small
for item in treebank.fileids():
    for tree in treebank.parsed_sents(item):
        productions += tree.productions()
    
print(len(productions))
# Out:
# <BracketParseCorpusReader in '.../corpora/treebank/combined' (not loaded yet)>
# 179360

# %%
productions[:10]
# Out:
# [S -> NP-SBJ VP .,
#  NP-SBJ -> NP , ADJP ,,
#  NP -> NNP NNP,
#  NNP -> 'Pierre',
#  NNP -> 'Vinken',
#  , -> ',',
#  ADJP -> NP JJ,
#  NP -> CD NNS,
#  CD -> '61',
#  NNS -> 'years']

# %% [markdown]
# The grammar can be induced as follows:

# %%
from nltk import Nonterminal
S = Nonterminal('S')
grammar = nltk.induce_pcfg(S, productions)

# %%
grammar.productions()[0]
# Out:
# S -> NP-SBJ VP . [0.162428]

# %% [markdown]
# ### 3.2. PCFG Parsers in NLTK
# NLTK provides several PCFG parsers:
#
# From `nltk.parse.viterbi`
#
# - ViterbiParser
#     - A bottom-up PCFG parser that uses dynamic programming to find the single most likely parse for a text. The ViterbiParser parser parses texts by filling in a “most likely constituent table”. This table records the most probable tree representation for any given span and node value. In particular, it has an entry for every start index, end index, and node value, recording the most likely subtree that spans from the start index to the end index, and has the given node value.
#
# From `nltk.parse.pchart` module
#
# - InsideChartParser
#     - A bottom-up parser for PCFG grammars that tries edges in descending order of the inside probabilities of their trees.
#     - use `beam_size = len(tokens)+1` argument
#
# - RandomChartParser
#     - A bottom-up parser for PCFG grammars that tries edges in random order. This sorting order results in a random search strategy.
#
# - UnsortedChartParser
#     - A bottom-up parser for PCFG grammars that tries edges in whatever order.
#
# - LongestChartParser
#     - A bottom-up parser for PCFG grammars that tries longer edges before shorter ones. This sorting order results in a type of best-first search strategy.
#
# Read about them in the [documentation](http://www.nltk.org/api/nltk.parse.html).

# %% [markdown]
# Let's parse one of the sentences from above using Viterbi parser.

# %%
parser = nltk.ViterbiParser(grammar)
for tree in parser.parse("Show me flights from New York to Los Angeles".split()):
    print(tree)
# Out:
# (S
#   (NP-SBJ (NNP Show))
#   (NP-PRD
#     (NP (NP (PRP me)) (NNS flights))
#     (PP
#       (IN from)
#       (NP
#         (NP (NNP New) (NNP York))
#         (PP (TO to) (NP (NNP Los) (NNP Angeles))))))) (p=1.23346e-35)

# %% [markdown]
# ### Exercise
#
# - Try different parser to parse the sentences from the exercises above
# - Compare assigned probabilities
# - Compare time it takes to parse sentences

# %%
tokenized_sentence = "show me flights from New York to Los Angeles".split()

# %%
import time

# %%
# %%time
# Parser 1: ViterbiParser
parser = nltk.ViterbiParser(grammar)
start_time = time.time()
for tree in parser.parse(tokenized_sentence):
    print(tree)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (S
#   (NP-SBJ (NN show))
#   (NP-PRD
#     (NP (NP (PRP me)) (NNS flights))
#     (PP
#       (IN from)
#       (NP
#         (NP (NNP New) (NNP York))
#         (PP (TO to) (NP (NNP Los) (NNP Angeles))))))) (p=2.0478e-35)
# --- 8.395040512084961 seconds ---
# CPU times: total: 8.2 s
# Wall time: 8.4 s

# %%
# %%time
# Parser 2: InsideChartParser (bottom-up parser for PCFG grammars that tries edges in descending order of the inside probabilities of their trees)
parser = nltk.InsideChartParser(grammar, beam_size = len(tokenized_sentence)+1)
start_time = time.time()

for tree in parser.parse(tokenized_sentence):
    print(tree)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.13099956512451172 seconds ---
# CPU times: total: 125 ms
# Wall time: 131 ms

# %%
# %%time
# Parser 3 : RandomChartParser (bottom-up parser for PCFG grammars that tries edges in random order. This sorting order results in a random search strategy.)
parser = nltk.RandomChartParser(grammar)
start_time = time.time()

for tree in parser.parse(tokenized_sentence):
    print(tree)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:5
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\pchart.py:261, in BottomUpProbabilisticChartParser.parse(self, tokens)
#     259     # Apply BU & FR to it.
#     260     queue.extend(bu.apply(chart, grammar, edge))
# --> 261     queue.extend(fr.apply(chart, grammar, edge))
#     263 # Get a list of complete parses.
#     264 parses = list(chart.parses(grammar.start(), ProbabilisticTree))
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\pchart.py:150, in SingleEdgeProbabilisticFundamentalRule.apply(self, chart, grammar, edge1)
#     145 else:
#     146     # edge2 = left_edge; edge1 = right_edge
#     147     for edge2 in chart.select(
#     148         end=edge1.start(), is_complete=False, nextsym=edge1.lhs()
#     149     ):
# --> 150         yield from fr.apply(chart, grammar, edge2, edge1)
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\pchart.py:124, in ProbabilisticFundamentalRule.apply(self, chart, grammar, left_edge, right_edge)
#     122 changed_chart = False
#     123 for cpl1 in chart.child_pointer_lists(left_edge):
# --> 124     if chart.insert(new_edge, cpl1 + (right_edge,)):
#     125         changed_chart = True
#     127 # If we changed the chart, then generate the edge.
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\chart.py:660, in Chart.insert(self, edge, *child_pointer_lists)
#     657     child_pointer_list = tuple(child_pointer_list)
#     658     if child_pointer_list not in cpls:
#     659         # It's a new CPL; register it, and return true.
# --> 660         cpls[child_pointer_list] = True
#     661         chart_was_modified = True
#     662 return chart_was_modified
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\collections.py:51, in OrderedDict.__setitem__(self, key, item)
#      49 def __setitem__(self, key, item):
#      50     dict.__setitem__(self, key, item)
# ---> 51     if key not in self._keys:
#      52         self._keys.append(key)
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\chart.py:202, in EdgeI.__eq__(self, other)
#     200 def __eq__(self, other):
#     201     return (
# --> 202         self.__class__ is other.__class__
#     203         and self._comparison_key == other._comparison_key
#     204     )
#
# KeyboardInterrupt:

# %%
# %%time
# Parser 4 : UnsortedChartParser (bottom-up parser for PCFG grammars that tries edges in whatever order.)
parser = nltk.UnsortedChartParser(grammar)
start_time = time.time()

for tree in parser.parse(tokenized_sentence):
    print(tree)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:5
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\pchart.py:260, in BottomUpProbabilisticChartParser.parse(self, tokens)
#     254         print(
#     255             "  %-50s [%s]"
#     256             % (chart.pretty_format_edge(edge, width=2), edge.prob())
#     257         )
#     259     # Apply BU & FR to it.
# --> 260     queue.extend(bu.apply(chart, grammar, edge))
#     261     queue.extend(fr.apply(chart, grammar, edge))
#     263 # Get a list of complete parses.
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\pchart.py:90, in ProbabilisticBottomUpPredictRule.apply(self, chart, grammar, edge)
#      88     return
#      89 for prod in grammar.productions():
# ---> 90     if edge.lhs() == prod.rhs()[0]:
#      91         new_edge = ProbabilisticTreeEdge.from_production(
#      92             prod, edge.start(), prod.prob()
#      93         )
#      94         if chart.insert(new_edge, ()):
#
# File ~\anaconda3\envs\NLU-LABs-venv\lib\site-packages\nltk\parse\chart.py:311, in TreeEdge.lhs(self)
#     310 def lhs(self):
# --> 311     return self._lhs
#
# KeyboardInterrupt:

# %% [markdown]
# Based on the experiment above, I see that the ViterbiParser is the better parser. It took almost 8 seconds and provides the trees. The InsideChartParser did computation very fast but did not match any parse. Other two parsers were taking too long to compute, I waited for 10 minutes and they were still running.

# %% [markdown]
# ## 4. Generating Sentences
#
# Grammars can be used to generate sentences as well. This is accomplished using `generate` method.
# read [here](http://www.nltk.org/api/nltk.parse.html#module-nltk.parse.generate)
#
# arguments it takes are the following `nltk.parse.generate.generate(grammar, start=None, depth=None, n=None)`:
#
# - grammar – The Grammar used to generate sentences.
# - start – The Nonterminal, which is and NLTK object, from which to start generate sentences.
# - depth – The maximal depth of the generated tree.
# - n – The maximum number of sentences to return.

# %%
from nltk.parse.generate import generate
toy_grammar = nltk.PCFG.fromstring(weighted_rules)
for sent in generate(toy_grammar, n=10):
    print(sent)
# Out:
# ['the', 'man', 'saw', 'the', 'man']
# ['the', 'man', 'saw', 'the', 'telescope']
# ['the', 'man', 'saw', 'a', 'man']
# ['the', 'man', 'saw', 'a', 'telescope']
# ['the', 'man', 'saw', 'the', 'man', 'with', 'the', 'man']
# ['the', 'man', 'saw', 'the', 'man', 'with', 'the', 'telescope']
# ['the', 'man', 'saw', 'the', 'man', 'with', 'a', 'man']
# ['the', 'man', 'saw', 'the', 'man', 'with', 'a', 'telescope']
# ['the', 'man', 'saw', 'the', 'man', 'with', 'the', 'man', 'with', 'the', 'man']
# ['the', 'man', 'saw', 'the', 'man', 'with', 'the', 'man', 'with', 'the', 'telescope']

# %%
for sent in generate(toy_grammar, n=10, depth=5):
    print(sent)
# Out:
# ['the', 'man', 'saw', 'the', 'man']
# ['the', 'man', 'saw', 'the', 'telescope']
# ['the', 'man', 'saw', 'a', 'man']
# ['the', 'man', 'saw', 'a', 'telescope']
# ['the', 'man', 'saw', 'I']
# ['the', 'telescope', 'saw', 'the', 'man']
# ['the', 'telescope', 'saw', 'the', 'telescope']
# ['the', 'telescope', 'saw', 'a', 'man']
# ['the', 'telescope', 'saw', 'a', 'telescope']
# ['the', 'telescope', 'saw', 'I']

# %%
for sent in generate(toy_grammar, n=10, start=Nonterminal('S')):
    print(sent)
# Out:
# ['the', 'man', 'saw', 'the', 'man']
# ['the', 'man', 'saw', 'the', 'telescope']
# ['the', 'man', 'saw', 'a', 'man']
# ['the', 'man', 'saw', 'a', 'telescope']
# ['the', 'man', 'saw', 'the', 'man', 'with', 'the', 'man']
# ['the', 'man', 'saw', 'the', 'man', 'with', 'the', 'telescope']
# ['the', 'man', 'saw', 'the', 'man', 'with', 'a', 'man']
# ['the', 'man', 'saw', 'the', 'man', 'with', 'a', 'telescope']
# ['the', 'man', 'saw', 'the', 'man', 'with', 'the', 'man', 'with', 'the', 'man']
# ['the', 'man', 'saw', 'the', 'man', 'with', 'the', 'man', 'with', 'the', 'telescope']

# %%
for sent in generate(toy_grammar, n=10, depth=5, start=Nonterminal('S')):
    print(sent)
# Out:
# ['the', 'man', 'saw', 'the', 'man']
# ['the', 'man', 'saw', 'the', 'telescope']
# ['the', 'man', 'saw', 'a', 'man']
# ['the', 'man', 'saw', 'a', 'telescope']
# ['the', 'man', 'saw', 'I']
# ['the', 'telescope', 'saw', 'the', 'man']
# ['the', 'telescope', 'saw', 'the', 'telescope']
# ['the', 'telescope', 'saw', 'a', 'man']
# ['the', 'telescope', 'saw', 'a', 'telescope']
# ['the', 'telescope', 'saw', 'I']

# %% [markdown]
# #### 4.1 Generating sequences with PCFG
# To used the probabilities on the production rules while generating, you can write your function or there is this library in python called [PCFG](https://github.com/thomasbreydo/pcfg).
# ```bash
# pip install pcfg
# ```
# The PCFG is fully compatible with NLTK, meaning that it task the same input as for `nltk.PCFG`, but it is limited as the only parameter available is the number of sentences that you want to generate.

# %%
# !pip install pcfg
# Out:
# Collecting pcfg
#   Using cached pcfg-0.1.5-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: nltk<4.0,>=3.5 in c:\users\adnan\anaconda3\envs\nlu-labs-venv\lib\site-packages (from pcfg) (3.8.1)
# Requirement already satisfied: importlib-metadata<4.0.0,>=3.1.1 in c:\users\adnan\anaconda3\envs\nlu-labs-venv\lib\site-packages (from pcfg) (3.10.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\adnan\anaconda3\envs\nlu-labs-venv\lib\site-packages (from importlib-metadata<4.0.0,>=3.1.1->pcfg) (3.11.0)
# Requirement already satisfied: click in c:\users\adnan\anaconda3\envs\nlu-labs-venv\lib\site-packages (from nltk<4.0,>=3.5->pcfg) (8.1.3)
# Requirement already satisfied: tqdm in c:\users\adnan\anaconda3\envs\nlu-labs-venv\lib\site-packages (from nltk<4.0,>=3.5->pcfg) (4.65.0)
# Requirement already satisfied: joblib in c:\users\adnan\anaconda3\envs\nlu-labs-venv\lib\site-packages (from nltk<4.0,>=3.5->pcfg) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\adnan\anaconda3\envs\nlu-labs-venv\lib\site-packages (from nltk<4.0,>=3.5->pcfg) (2022.10.31)
# Requirement already satisfied: colorama in c:\users\adnan\anaconda3\envs\nlu-labs-venv\lib\site-packages (from click->nltk<4.0,>=3.5->pcfg) (0.4.6)
# Installing collected packages: pcfg
# Successfully installed pcfg-0.1.5

# %%
from pcfg import PCFG
toy_grammar = PCFG.fromstring(weighted_rules)
for sent in toy_grammar.generate(10):
    print(sent)
# Out:
# the man saw I with the telescope with the man
# a telescope saw the man with the telescope with the telescope
# a man saw a telescope with a telescope with a telescope with the telescope with a telescope with the telescope
# a man with the telescope with the telescope with a telescope with a telescope saw a telescope with the man with the telescope with a man with a man
# a telescope saw a man with the telescope
# a telescope with a man saw the telescope
# a man with a man saw the man with the man with I
# a man with a man with the man saw the man with a telescope
# the man saw I
# I saw a telescope with a man

# %% [markdown]
# #### 4.2 Generating sequences with PCFG (New version)
# Recently, a>>> from pcfg import PCFG student of the NLU course has released a modified version of the pcfg library implementing two missing features namely `start` and `depth`. You can find this [here](https://github.com/halixness/pcfg).

# %%
from pcfg import PCFG

grammar = PCFG.fromstring("""
S -> Subject Action [1.0]
Subject -> "a cow" [0.7] | "some guy" [0.1] | "the woman" [0.2]
Action -> "eats lunch" [0.5] | "was here" [0.5]
""")

# %%
for sentence in grammar.generate(n=3, depth=5, start=Nonterminal("S")):
    print(sentence)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 for sentence in grammar.generate(n=3, depth=5, start=Nonterminal("S")):
#       2     print(sentence)
#
# TypeError: generate() got an unexpected keyword argument 'depth'

# %% [markdown]
# ## 5. Evaluating Constituency Parsers

# %% [markdown]
# ### 5.1. Comparing Trees

# %% [markdown]
# Since _constituency parser_ outputs _constituents_, parser evaluation is essentially a comparison between constituents of the reference and the automatic (hypothesis) parse trees (of the test set). Since constituents are labeled (have _syntactic categories_), the evaluation can also compare the reference and the hypothesis labels.
#
# A constituent in a hypothesis parse tree is considered correct, if there is a constituent in a reference parse tree that has the same span and label. That is:
#
# - has the same starting point
# - has the same ending point
# - has the same non-terminal symbol

# %% [markdown]
# Using this information we can compute precision and recall for the parser, as:
#
# $$ \text{recall} = \frac{\text{# of correct constituents in hypothesis}}{\text{# of constituents in reference}}$$
#
# $$ \text{precision} = \frac{\text{# of correct constituents in hypothesis}}{\text{# of constituents in hypothesis}}$$
#
# The $F_1$ metric is computed the usual way, as:
#
# $$F_1 = \frac{2PR}{P+R}$$

# %% [markdown]
# In case for the correct constituent counts we consider labels, we compute _labeled_ precision and recall. Otherwise, metrics are _unlabeled_ (i.e. we just consider the span not the label).

# %% [markdown]
# ### 5.2. PARSEVAL
# The evaluation method that implements this is known as **PARSEVAL** [(Black et al., 1991)](https://aclanthology.org/H91-1060/).
#
# The metric includes an algorithm from _caninicalization_ that removes grammar-specific information and allows comparing parsers with different grammars.
#
# The "canonical" implementation of **PARSEVAL** is known as [**EVALB**](https://nlp.cs.nyu.edu/evalb/).

# %% [markdown]
# Since constitents are essentially sub-trees of a sentence parse tree, while having the same label and start and end points, they might differ in their internal structure.
#
# e.g.: `((A B) C)` vs. `(A (B C))`
#
# Consequently, there is an additional metric in **PARSEVAL** that is used to account for this -- **cross-brackets** (since parse trees are represented using bracketed notation) -- which is a simple count of such cases per sentence.
#
# However, since `((A B) C)` and `(A (B C))` have different constituents, this is already reflected in precision and recall.

# %% [markdown]
# ### 5.1. EVALB (PYTHON)
# There is no officially supported EVALB for python. However, there are few implementations available.
# The most easy to use it [PYEVALB](https://github.com/flyaway1217/PYEVALB).
#
# It is possible to compare two parse trees as the following:

# %%
# !pip install PYEVALB

# %%
#!pip install PYEVALB
from PYEVALB import scorer as eval_scorer
from PYEVALB import parser as eval_parser

pt0 = "(S (NP (PRON I)) (VP (V saw) (NP (Det the) (N man)) (PP (P with) (NP (Det a) (N telescope)))))"
pt1 = "(S (NP (PRON I)) (VP (V saw) (NP (Det the) (N man) (PP (P with) (NP (Det a) (N telescope))))))"

pt0_tree = eval_parser.create_from_bracket_string(pt0)
pt1_tree = eval_parser.create_from_bracket_string(pt1)

s = eval_scorer.Scorer()
result = s.score_trees(pt0_tree, pt1_tree)

# %%
print("P: {} R: {}".format(round(result.prec, 2), round(result.recall, 2)))
# Out:
# P: 0.83 R: 0.83

# %% [markdown]
# ## Lab Exercise
# - Write two or more sentences of your choice.
# - Write a PCFG that models your sentences.
# - To validate your grammar, parse the sentences with a parser of your choice.
# - Then, generate 10 sentences  using a PCFG by experimenting with `nltk.parse.generate.generate` using different starting symbols and depths. Optionally, generate 10 sentences with PCFG.generate() (see section 4).

# %%
from pcfg import PCFG
import nltk

# %%
# Sentences of my choice.
sentences = [
    'The cat chased mouse',
    'The sun set over horizon',
]

# PCFG grammar rules for the sentences.
rules = [
    'S -> NP VP [1.0]',
    'NP -> Det N [0.5] | N [0.5]',
    'VP -> V NP [0.5] | V PP [0.5]',
    'PP -> P NP [1.0]',
    "Det -> 'The' [1.0]",
    'N -> "cat" [0.25] | "mouse" [0.25] | "sun" [0.25] | "horizon" [0.25]',
    'V -> "chased" [0.5] | "set" [0.5]',
    'P -> "over" [1.0]'
]

# %%
# PCFG model
grammar = PCFG.fromstring(rules)

# Validation of grammar by parsing the sentences with ViterbiParser
parser = nltk.ViterbiParser(grammar)
for sentence in sentences:
    print(sentence)
    for tree in parser.parse(sentence.split()):
        tree.pretty_print()
        print()
# Out:
# The cat chased mouse
#              S
#       _______|__________
#      |                  VP
#      |             _____|____
#      NP           |          NP
#   ___|___         |          |
# Det      N        V          N
#  |       |        |          |
# The     cat     chased     mouse
#
#
# The sun set over horizon
#              S
#       _______|___
#      |           VP
#      |        ___|____
#      |       |        PP
#      |       |    ____|_____
#      NP      |   |          NP
#   ___|___    |   |          |
# Det      N   V   P          N
#  |       |   |   |          |
# The     sun set over     horizon

# %%
# Then, generate 10 sentences using a PCFG by experimenting with nltk.parse.generate.generate
for sent in grammar.generate(10):
    print(sent)
# Out:
# The mouse chased mouse
# The mouse chased over The mouse
# The mouse set The mouse
# The sun chased sun
# The mouse chased over mouse
# mouse chased over The sun
# cat chased The sun
# mouse chased mouse
# The sun chased cat
# The horizon set over horizon
